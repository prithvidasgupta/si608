# %%
import glob

import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
from pathlib import Path
import re
import glob

import pylab as p
from tqdm import tqdm
import gzip
import random
import numpy as np
from collections import defaultdict
from scipy.sparse import csr_matrix, diags, lil_matrix
from scipy.sparse.linalg import eigs

np.random.RandomState(42)
# Out:
# RandomState(MT19937) at 0x132252840

# %%
# Ugly duplication of code
def load_data(filepath, headers=None, sep="\t", bad_lines="warn"):
    """
    Loads clickstream data and performs basic cleaning (lowercasing and dropping NaNs).
    :param bad_lines: Defines what to do when encountering a line with too many fields
    :type bad_lines: str (default: "warn")
    :param sep: Delimiter in file.
    :type sep: str
    :param headers: Column headers for file.
    :type headers: list (default: clickstream headers)
    :param filepath: Path to file.
    :type filepath: str
    :return: Cleaned data loaded from given file.
    :rtype: pandas dataframe
    """
    if headers is None:
        headers = ["prev", "curr", "type", "n"]
    filepath = str(filepath)
    if filepath.endswith(".gz"):
        with gzip.open(filepath, "rt", encoding="utf-8") as file_obj:
            clickstream = pd.read_csv(
                file_obj, sep=sep, names=headers, on_bad_lines=bad_lines
            )
    else:
        clickstream = pd.read_csv(
            filepath, sep=sep, names=headers, on_bad_lines=bad_lines
        )
    cols = clickstream.columns
    for col in tqdm(cols, desc="Processing text"):
        try:
            if clickstream[col].dtype == "O":
                clickstream.loc[:, col] = clickstream[col].str.lower()
        except AttributeError as e:
            print(f"Check for non-string datatypes: {e}")
    clickstream.dropna(inplace=True)
    return clickstream


def get_paths(directory, pattern):
    """
    Creates list of filepaths matching the given pattern in the given directory.
    :param directory: Directory containing files of interest.
    :type directory: str
    :param pattern: Pattern of filenames of interest.
    :type pattern: str
    :return: All filenames matching the given pattern in the given directory.
    :rtype: list of strings
    """
    directory_path = Path(directory)
    return directory_path.glob(pattern)


def build_graph(df, from_node="prev", to_node="curr", weight="n"):
    """
    Creates directed graph from given dataframe, with edge weights equal to clicks.
    :param df: Pages with clickstream data.
    :type df: Dataframe
    :param from_node: Name of column containing click origin pages
    :type from_node: str
    :param to_node: Name of column where containing click destination pages
    :type to_node: str
    :param weight: Number of clicks
    :type weight: int
    :return: Clickstream graph
    :rtype: NetworkX object
    """
    g = nx.DiGraph()
    from_nodes = list(df[from_node])
    to_nodes = list(df[to_node])
    weights = list(df[weight])

    for fnode, tnode, wt in zip(from_nodes, to_nodes, weights):
        if fnode == tnode:
            print(f" WARN: self-edge {fnode, tnode}")
        g.add_edge(fnode, tnode, weight=wt)
    return g


def get_node_map(g):
    node_mapping = {node: i for i, node in enumerate(g.nodes)}
    return node_mapping


def get_state_dis(transition_matrix):
    """
    Assumes equal probability at initial state. Not sure I need this function?
    :param transition_matrix:
    :type transition_matrix:
    :return:
    :rtype:
    """
    state_dis = np.full(
        (1, transition_matrix.shape[0]), (1 / transition_matrix.shape[0])
    )
    return state_dis


def get_stationary_dis(transition_matrix):
    """
    https://phys.libretexts.org/Bookshelves/Mathematical_Physics_and_Pedagogy/Computational_Physics_(Chong)/08%3A_Sparse_Matrices/8.03%3A_Using_Sparse_Matrices
    :param transition_matrix: column stochastic
    :type transition_matrix:
    :return:
    :rtype:
    """
    eig_vals, eig_vecs = eigs(transition_matrix)
    stationary_idx = np.where(np.isclose(eig_vals, 1))[0][0]
    stationary_vec = eig_vecs[:, stationary_idx].real

    # Normalize vector
    stationary_vec = np.abs(stationary_vec)
    stationary_vec /= np.sum(stationary_vec)
    return stationary_vec


# def get_transition_matrix(g):
#     num_nodes = g.number_of_nodes()
#     node_mapping = get_node_map(g)
#     row_idx = []
#     col_idx = []
#     data = []

#     for node in g.nodes:
#         out_edges = list(g.out_edges(node))
#         if len(out_edges) == 0:
#             out_edges = [(node, other_node) for other_node in g.nodes]
#             out_weights = [1.0 / num_nodes for _ in range(num_nodes)]
#         else:
#             out_weights = [g.edges[edge]["weight"] for edge in out_edges]
#         total_weights = sum(out_weights)
#         if total_weights > 0:
#             normalized_weights = [w / total_weights for w in out_weights]
#             row_idx.extend([node_mapping[node]] * len(out_edges))
#             col_idx.extend([node_mapping[j] for i, j in out_edges])
#             data.extend(normalized_weights)
#     trans_matrix = csr_matrix(
#         (data, (row_idx, col_idx)), shape=(num_nodes, num_nodes), dtype=np.float64
#     )

#     # column_sums = trans_matrix.sum(axis=0)
#     # sinks = np.asarray(column_sums == 0).flatten()
#     # if np.any(sinks):
#     #     uniform_vec = np.full(num_nodes, 1 / num_nodes)
#     #     sink_locs = np.where(sinks)[0]
#     #     for loc in sink_locs:
#     #         trans_matrix[:,loc] = uniform_vec

#     # Make column stochastic
#     col_stoch_trans_matrix = trans_matrix.transpose()
#     return col_stoch_trans_matrix


# def get_transition_matrix(g):
#     num_nodes = g.number_of_nodes()
#     node_mapping = {node: i for i, node in enumerate(g.nodes)}
#     row_idx = []
#     col_idx = []
#     data = []
# 
#     for node in g.nodes:
#         out_edges = list(g.out_edges(node))
#         out_weights = [g.edges[edge]["weight"] for edge in out_edges]
#         total_weights = sum(out_weights)
#         if total_weights > 0:
#             normalized_weights = [w / total_weights for w in out_weights]
#             row_idx.extend([node_mapping[node]] * len(out_edges))
#             col_idx.extend([node_mapping[j] for i, j in out_edges])
#             data.extend(normalized_weights)
#     trans_matrix = csr_matrix((data, (row_idx, col_idx)), shape=(num_nodes, num_nodes), dtype=np.float64)
#     column_sums = trans_matrix.sum(axis=0)
#     sinks = np.asarray(column_sums == 0).flatten()
#     if np.any(sinks):
#         uniform_vec = np.full(num_nodes, 1 / num_nodes)
#         sink_locs = np.where(sinks)[0]
#         for loc in sink_locs:
#             trans_matrix[:,loc] = uniform_vec
# 
#     # Make column stochastic
#     col_stoch_trans_matrix = trans_matrix.transpose()
#     return col_stoch_trans_matrix

# def get_transition_matrix(g):
#     num_nodes = g.number_of_nodes()
#     node_mapping = get_node_map(g)
#     row_idx = []
#     col_idx = []
#     data = []
#     
#     for node in g.nodes:
#         out_edges = list(g.out_edges(node))
#         out_weights = [g.edges[edge]["weight"] for edge in out_edges]
#         total_weights = sum(out_weights)
#         if total_weights > 0:
#             normalized_weights = [w / total_weights for w in out_weights]
#             row_idx.extend([node_mapping[node]] * len(out_edges))
#             col_idx.extend([node_mapping[j] for i, j in out_edges])
#             data.extend(normalized_weights)
#         # Set teleport probabilities for sinks
#         else:
#             row_idx.extend([node_mapping[node]] for _ in range(num_nodes))
#             col_idx.extend(range(num_nodes))
#             data.extend([1/num_nodes]*num_nodes)
#     trans_matrix = csr_matrix((data, (row_idx, col_idx)), shape=(num_nodes, num_nodes), dtype=np.float64)
#     
#     # Check for sinks and replace with 1/num_nodes:
#     # column_sums = trans_matrix.sum(axis=0)
#     # sinks = np.asarray(column_sums == 0).flatten()
#     # uniform_prob = 1 / num_nodes
#     # trans_matrix = trans_matrix.tolil()  
#     # trans_matrix[:, sinks] = uniform_prob
#     # trans_matrix = trans_matrix.tocsr()
# 
#     # Make column stochastic
#     col_stoch_trans_matrix = trans_matrix.transpose()
#     return col_stoch_trans_matrix

# def get_transition_matrix(g):
#     num_nodes = g.number_of_nodes()
#     node_mapping = {node: i for i, node in enumerate(g.nodes)}
#     row_idx = []
#     col_idx = []
#     data = []
#     for node in g.nodes:
#         out_edges = list(g.out_edges(node))
#         out_weights = [g.edges[edge]["weight"] for edge in out_edges]
#         total_weights = sum(out_weights)
#         if total_weights > 0:
#             normalized_weights = [w / total_weights for w in out_weights]
#             row_idx.extend([node_mapping[node]] * len(out_edges))
#             col_idx.extend([node_mapping[j] for i, j in out_edges])
#             data.extend(normalized_weights)
#     trans_matrix = csr_matrix((data, (row_idx, col_idx)), shape=(num_nodes, num_nodes), dtype=np.float64)
#     # Handle sink nodes
#     column_sums = trans_matrix.sum(axis=0)
#     sinks = np.asarray(column_sums == 0).flatten()
#     if np.any(sinks):
#         uniform_prob = 1 / num_nodes
#         sink_adjustment = csr_matrix((uniform_prob, (np.arange(num_nodes), np.where(sinks)[0])),
#                                      shape=(num_nodes, num_nodes))
#         trans_matrix += sink_adjustment
#     # Ensure the matrix is column stochastic
#     col_sums = np.array(trans_matrix.sum(axis=0)).flatten()
#     col_stoch_trans_matrix = trans_matrix / col_sums
#     return col_stoch_trans_matrix.transpose()


def get_transition_matrix(g):
    # Add node to distribute sinks uniformly
    g.add_node("sink_bridge")
    node_mapping = get_node_map(g)
    num_nodes = g.number_of_nodes()
    
    row_idx = []
    col_idx = []
    data = []
    
    for node in g.nodes:
        out_edges = list(g.out_edges(node))
        out_weights = [g.edges[edge]["weight"] for edge in out_edges]
        total_weights = sum(out_weights)
        
        if total_weights > 0:
            normalized_weights = [w / total_weights for w in out_weights]
            row_idx.extend([node_mapping[node]] * len(out_edges))
            col_idx.extend([node_mapping[j] for i, j in out_edges])
            data.extend(normalized_weights)
        else:
            g.add_edge(node, 'sink_bridge', weight=1)
            row_idx.append(node_mapping[node])
            col_idx.append(node_mapping['sink_bridge'])
            data.append(1)
    for node in g.nodes:
        if node != 'sink_bridge':
            g.add_edge('sink_bridge', node, weight=1/num_nodes)
            row_idx.append(node_mapping['sink_bridge'])
            col_idx.append(node_mapping[node])
            data.append(1/num_nodes)
    trans_matrix = csr_matrix((data, (row_idx, col_idx)), shape=(num_nodes, num_nodes), dtype=np.float64)
    return trans_matrix.transpose()


def test_transition_matrix(transition_matrix):
    column_sums = transition_matrix.sum(axis=0)
    non_zero_cols = column_sums > 0
    sinks = column_sums == 0
    print(f"Sinks: {np.count_nonzero(sinks)}")
    print(f"Non-zero cols: {np.count_nonzero(non_zero_cols)}")
    print("Non-zero cols are stochastic:")
    return np.allclose(
        column_sums[non_zero_cols], np.ones(column_sums[non_zero_cols].shape), atol=1e-6
    )


def random_walk(
    g, trans_matrix, stationary_matrix, start, max_length=1e5, converge_threshold=1e-5
):
    # Initialize dict of visited pages
    visited = defaultdict(int)

    # Set starting node
    node_list = list(g.nodes())
    start_page = node_list.index(start)
    page = np.zeros(len(node_list))
    page[start_page] = 1

    # Initialize progress bar
    pbar = tqdm(total=max_length)
    pbar.set_description("Random Walker Progress")

    # Run random walk until convergence or max iterations reached
    iteration = 0
    while True:
        transition_probs = trans_matrix.dot(page)
        # Test normalizing transition_probs
        transition_probs /= transition_probs.sum()
        visit = np.random.choice(len(page), p=transition_probs)
        visited[visit] += 1
        page = np.zeros_like(page)
        page[visit] = 1
        iteration += 1
        pbar.update(1)

        if iteration % 100 == 0 or iteration >= max_length:
            curr_state = page / page.sum()
            error = np.abs(curr_state - stationary_matrix).sum()

            if error < converge_threshold or iteration >= max_length:
                break
    pbar.close()
    return visited, visit

# %% [markdown]
# ## Test Random Walker

# %%
subset = pd.read_pickle("../all_nodes.pkl")
wiki_201901 = load_data("../data/2017-2023/clickstream-enwiki-2019-01.tsv.gz")
# Out:
# Processing text: 100%|██████████| 4/4 [00:09<00:00,  2.30s/it]

# %%
filter_201901 = wiki_201901[
    (wiki_201901["prev"].isin(page.lower() for page in subset))
    & (wiki_201901["curr"].isin(page.lower() for page in subset))
]

# %%
graph_201901 = build_graph(filter_201901)
len(graph_201901)
# Out:
#  WARN: self-edge ('the_oa', 'the_oa')
#  WARN: self-edge ('grand_theft_auto', 'grand_theft_auto')
#  WARN: self-edge ('canteen', 'canteen')
#  WARN: self-edge ('vic', 'vic')
#  WARN: self-edge ('fear_of_the_dark', 'fear_of_the_dark')
#  WARN: self-edge ('lala', 'lala')
#  WARN: self-edge ('bet', 'bet')
#  WARN: self-edge ('raptor', 'raptor')
#  WARN: self-edge ('ys', 'ys')
#  WARN: self-edge ('sugar_baby', 'sugar_baby')
#  WARN: self-edge ('awal', 'awal')
#  WARN: self-edge ('genx', 'genx')
#  WARN: self-edge ('python', 'python')
#  WARN: self-edge ('spice', 'spice')
#  WARN: self-edge ("death's_head", "death's_head")
#  WARN: self-edge ('nxt', 'nxt')
#  WARN: self-edge ('total_depravity', 'total_depravity')
#  WARN: self-edge ('jamaica_station', 'jamaica_station')
#  WARN: self-edge ('bec', 'bec')
#  WARN: self-edge ('deadbeef', 'deadbeef')
#  WARN: self-edge ('y_combinator', 'y_combinator')
#  WARN: self-edge ('tops', 'tops')
#  WARN: self-edge ('ariel', 'ariel')
#  WARN: self-edge ('clip', 'clip')
#  WARN: self-edge ('philadelphia_soul', 'philadelphia_soul')
#  WARN: self-edge ('bet', 'bet')
#  WARN: self-edge ('claim_jumper', 'claim_jumper')
#  WARN: self-edge ('ios', 'ios')
#  WARN: self-edge ('gyro', 'gyro')
#  WARN: self-edge ('killing_machine', 'killing_machine')
#  WARN: self-edge ('salad_days', 'salad_days')
#  WARN: self-edge ('atomic_blonde', 'atomic_blonde')
#  WARN: self-edge ('neet', 'neet')
#  WARN: self-edge ('kaws', 'kaws')
#  WARN: self-edge ('neet', 'neet')
#  WARN: self-edge ('second_wind', 'second_wind')
#  WARN: self-edge ('shim', 'shim')
#  WARN: self-edge ('bill_of_rights', 'bill_of_rights')
#  WARN: self-edge ('black_moon', 'black_moon')
#  WARN: self-edge ('airport', 'airport')
#  WARN: self-edge ('rock_candy', 'rock_candy')
#  WARN: self-edge ('leh', 'leh')
#  WARN: self-edge ('imac', 'imac')
#  WARN: self-edge ('red_wine', 'red_wine')
#  WARN: self-edge ('talc', 'talc')
#  WARN: self-edge ('kith', 'kith')
#  WARN: self-edge ('jet_black', 'jet_black')
#  WARN: self-edge ('putty', 'putty')
#  WARN: self-edge ('ys', 'ys')
#  WARN: self-edge ('donkey_show', 'donkey_show')
#  WARN: self-edge ('hush_puppies', 'hush_puppies')
#  WARN: self-edge ('femme_fatale', 'femme_fatale')
#  WARN: self-edge ('rai', 'rai')
#  WARN: self-edge ('wu_wei', 'wu_wei')
#  WARN: self-edge ('harm', 'harm')
#  WARN: self-edge ('back_to_school', 'back_to_school')
#  WARN: self-edge ('cannon_fodder', 'cannon_fodder')
#  WARN: self-edge ('auk', 'auk')
#  WARN: self-edge ('regenesis', 'regenesis')
#  WARN: self-edge ('the_well', 'the_well')
#  WARN: self-edge ('chud', 'chud')
#  WARN: self-edge ('piat', 'piat')
#  WARN: self-edge ('yang', 'yang')
#  WARN: self-edge ('rough_diamond', 'rough_diamond')
#  WARN: self-edge ('shades_of_black', 'shades_of_black')
#  WARN: self-edge ('body_count', 'body_count')
#  WARN: self-edge ('sampson', 'sampson')
#  WARN: self-edge ('esri', 'esri')
#  WARN: self-edge ('pep', 'pep')
#  WARN: self-edge ('ops', 'ops')
#  WARN: self-edge ('edo', 'edo')
#  WARN: self-edge ('asma', 'asma')
#  WARN: self-edge ('galley_slave', 'galley_slave')
#  WARN: self-edge ('fucked_up', 'fucked_up')
#  WARN: self-edge ('suse', 'suse')
#  WARN: self-edge ('slippery_slope', 'slippery_slope')
#  WARN: self-edge ('turbojet', 'turbojet')
#  WARN: self-edge ('nic', 'nic')
#  WARN: self-edge ('salt_lake', 'salt_lake')
#  WARN: self-edge ('gic', 'gic')
#  WARN: self-edge ('chips', 'chips')
#  WARN: self-edge ('esso', 'esso')
#  WARN: self-edge ('iah', 'iah')
#  WARN: self-edge ('solid', 'solid')
#  WARN: self-edge ('pi', 'pi')
#  WARN: self-edge ('atos', 'atos')
#  WARN: self-edge ('isco', 'isco')
#  WARN: self-edge ('pe', 'pe')
#  WARN: self-edge ('set_list', 'set_list')
#  WARN: self-edge ('talk_radio', 'talk_radio')
#  WARN: self-edge ('order_of_merit', 'order_of_merit')
#  WARN: self-edge ('taz', 'taz')
#  WARN: self-edge ('bric', 'bric')
#  WARN: self-edge ('middle_finger', 'middle_finger')
#  WARN: self-edge ('steel_mill', 'steel_mill')
#  WARN: self-edge ('gimp', 'gimp')
#  WARN: self-edge ('high_fantasy', 'high_fantasy')
#  WARN: self-edge ('wonder_boy', 'wonder_boy')
#  WARN: self-edge ('martini', 'martini')
#  WARN: self-edge ('uel', 'uel')
#  WARN: self-edge ('messenger', 'messenger')
#  WARN: self-edge ('rae', 'rae')
#  WARN: self-edge ('meco', 'meco')
#  WARN: self-edge ('nuc', 'nuc')
#  WARN: self-edge ('mom_jeans', 'mom_jeans')
#  WARN: self-edge ('starforce', 'starforce')
#  WARN: self-edge ('blackberry', 'blackberry')
#  WARN: self-edge ('coa', 'coa')
#  WARN: self-edge ('fan_death', 'fan_death')
#  WARN: self-edge ('virtual_console', 'virtual_console')
#  WARN: self-edge ('fallout_shelter', 'fallout_shelter')
#  WARN: self-edge ('order_of_merit', 'order_of_merit')
#  WARN: self-edge ('animal_cognition', 'animal_cognition')
#  WARN: self-edge ('nine_days', 'nine_days')
#  WARN: self-edge ('ola', 'ola')
#  WARN: self-edge ('shark', 'shark')
#  WARN: self-edge ('lac', 'lac')
#  WARN: self-edge ('bal', 'bal')
#  WARN: self-edge ('iron_maiden', 'iron_maiden')
#  WARN: self-edge ('moo', 'moo')
#  WARN: self-edge ('crimes_and_misdemeanors', 'crimes_and_misdemeanors')
#  WARN: self-edge ('sni', 'sni')
#  WARN: self-edge ('tail_gunner', 'tail_gunner')
#  WARN: self-edge ('metric', 'metric')
#  WARN: self-edge ('coa', 'coa')
#  WARN: self-edge ('gia', 'gia')
#  WARN: self-edge ('luna', 'luna')
#  WARN: self-edge ('rut', 'rut')
#  WARN: self-edge ('cas', 'cas')
#  WARN: self-edge ('polar_bear', 'polar_bear')
#  WARN: self-edge ('meu', 'meu')
#  WARN: self-edge ('dwarf', 'dwarf')
#  WARN: self-edge ('tvri', 'tvri')
#  WARN: self-edge ('solid', 'solid')
#  WARN: self-edge ('init', 'init')
#  WARN: self-edge ('freezer_burn', 'freezer_burn')
#  WARN: self-edge ('chalet', 'chalet')
#  WARN: self-edge ('bad_manners', 'bad_manners')
#  WARN: self-edge ('night_terror', 'night_terror')
#  WARN: self-edge ('opium_den', 'opium_den')
#  WARN: self-edge ('banya', 'banya')
#  WARN: self-edge ('boa', 'boa')
#  WARN: self-edge ('text', 'text')
#  WARN: self-edge ('secret_service', 'secret_service')
#  WARN: self-edge ('stem', 'stem')
#  WARN: self-edge ('regenesis', 'regenesis')
#  WARN: self-edge ('imac', 'imac')
#  WARN: self-edge ('night_fever', 'night_fever')
#  WARN: self-edge ('airport', 'airport')
#  WARN: self-edge ('cocoa', 'cocoa')
#  WARN: self-edge ('ideal', 'ideal')
#  WARN: self-edge ('stax', 'stax')
#  WARN: self-edge ('eliza', 'eliza')
#  WARN: self-edge ('iron_maiden', 'iron_maiden')
#  WARN: self-edge ('girl_next_door', 'girl_next_door')
#  WARN: self-edge ('insight', 'insight')
#  WARN: self-edge ('dondi', 'dondi')
#  WARN: self-edge ('warp_drive', 'warp_drive')
#  WARN: self-edge ('val', 'val')
#  WARN: self-edge ('dbm', 'dbm')
#  WARN: self-edge ('pide', 'pide')
#  WARN: self-edge ('speech_act', 'speech_act')
#  WARN: self-edge ('can', 'can')
#  WARN: self-edge ('minor_scale', 'minor_scale')
#  WARN: self-edge ('high_fantasy', 'high_fantasy')
#  WARN: self-edge ('era', 'era')
#  WARN: self-edge ('stardate', 'stardate')
#  WARN: self-edge ('pulp_fiction', 'pulp_fiction')
#  WARN: self-edge ('soko', 'soko')
#  WARN: self-edge ('wedding_anniversary', 'wedding_anniversary')
#  WARN: self-edge ('whipped_cream', 'whipped_cream')
#  WARN: self-edge ('broken_heart', 'broken_heart')
#  WARN: self-edge ('silver_bullet', 'silver_bullet')
#  WARN: self-edge ('full_house', 'full_house')
#  WARN: self-edge ('asp', 'asp')
#  WARN: self-edge ('ak', 'ak')
#  WARN: self-edge ('wrecking_ball', 'wrecking_ball')
#  WARN: self-edge ('3i', '3i')
#  WARN: self-edge ('electric_universe', 'electric_universe')
#  WARN: self-edge ('alb', 'alb')
#  WARN: self-edge ('army_men', 'army_men')
#  WARN: self-edge ('femme_fatale', 'femme_fatale')
#  WARN: self-edge ('private_dancer', 'private_dancer')
#  WARN: self-edge ('web', 'web')
#  WARN: self-edge ('koin', 'koin')
#  WARN: self-edge ('iad', 'iad')
#  WARN: self-edge ('hard_target', 'hard_target')
#  WARN: self-edge ('love_hotel', 'love_hotel')
#  WARN: self-edge ('mai', 'mai')
#  WARN: self-edge ('ico', 'ico')
#  WARN: self-edge ('suburbia_(film)', 'suburbia_(film)')
#  WARN: self-edge ('iio', 'iio')
#  WARN: self-edge ('fop', 'fop')
#  WARN: self-edge ('tcl', 'tcl')
#  WARN: self-edge ('road_to_nowhere', 'road_to_nowhere')
#  WARN: self-edge ('alde', 'alde')
#  WARN: self-edge ('moose', 'moose')
#  WARN: self-edge ('kink', 'kink')
#  WARN: self-edge ('amor_fati', 'amor_fati')
#  WARN: self-edge ('woo', 'woo')
#  WARN: self-edge ('personal_shopper', 'personal_shopper')
#  WARN: self-edge ('upn', 'upn')
#  WARN: self-edge ('circular_breathing', 'circular_breathing')
#  WARN: self-edge ('feta', 'feta')
#  WARN: self-edge ('osh', 'osh')
#  WARN: self-edge ('necessary_evil', 'necessary_evil')
#  WARN: self-edge ('dox', 'dox')
#  WARN: self-edge ('claris', 'claris')
#  WARN: self-edge ('person_of_interest', 'person_of_interest')
#  WARN: self-edge ('master_and_servant', 'master_and_servant')
#  WARN: self-edge ('edgar', 'edgar')
#  WARN: self-edge ('treepeople', 'treepeople')
#  WARN: self-edge ('flit', 'flit')
#  WARN: self-edge ('raptor', 'raptor')
#  WARN: self-edge ('scar_tissue', 'scar_tissue')
#  WARN: self-edge ('minimum_viable_product', 'minimum_viable_product')
#  WARN: self-edge ('new_start', 'new_start')
#  WARN: self-edge ('lola', 'lola')
#  WARN: self-edge ('flashforward', 'flashforward')
#  WARN: self-edge ('claris', 'claris')
#  WARN: self-edge ('person_of_interest', 'person_of_interest')
#  WARN: self-edge ('snafu', 'snafu')
#  WARN: self-edge ('parliamentary_republic', 'parliamentary_republic')
#  WARN: self-edge ('minor_scale', 'minor_scale')
#  WARN: self-edge ('army_men', 'army_men')
#  WARN: self-edge ('body_double', 'body_double')
#  WARN: self-edge ('vision_quest', 'vision_quest')
#  WARN: self-edge ('saddle_point', 'saddle_point')
#  WARN: self-edge ('cuda', 'cuda')
#  WARN: self-edge ('amy_macdonald', 'amy_macdonald')
#  WARN: self-edge ('wem', 'wem')
#  WARN: self-edge ('odessa', 'odessa')
#  WARN: self-edge ("lorenzo's_oil", "lorenzo's_oil")
#  WARN: self-edge ('ask', 'ask')
#  WARN: self-edge ('sweet_pea', 'sweet_pea')
#  WARN: self-edge ('strawberry_shortcake', 'strawberry_shortcake')
#  WARN: self-edge ('spring_green', 'spring_green')
#  WARN: self-edge ('spectre', 'spectre')
#  WARN: self-edge ('blank_space', 'blank_space')
#  WARN: self-edge ('bric', 'bric')
#  WARN: self-edge ('sasa', 'sasa')
#  WARN: self-edge ('fresh_cream', 'fresh_cream')
#  WARN: self-edge ('fnac', 'fnac')
#  WARN: self-edge ('ikon', 'ikon')
#  WARN: self-edge ('pulp_fiction', 'pulp_fiction')
#  WARN: self-edge ('airpod', 'airpod')
#  WARN: self-edge ('scs', 'scs')
#  WARN: self-edge ('geb', 'geb')
#  WARN: self-edge ('mix', 'mix')
#  WARN: self-edge ('air_supply', 'air_supply')
#  WARN: self-edge ('river_city', 'river_city')
#  WARN: self-edge ('tetris_effect', 'tetris_effect')
#  WARN: self-edge ('slippery_slope', 'slippery_slope')
#  WARN: self-edge ('liga', 'liga')
#  WARN: self-edge ('acas', 'acas')
#  WARN: self-edge ('radius', 'radius')
#  WARN: self-edge ('jit', 'jit')
#  WARN: self-edge ('lany', 'lany')
#  WARN: self-edge ('nus', 'nus')
#  WARN: self-edge ('fits', 'fits')
#  WARN: self-edge ('gef', 'gef')
#  WARN: self-edge ('tora', 'tora')
#  WARN: self-edge ('chuck', 'chuck')
#  WARN: self-edge ('basic', 'basic')
#  WARN: self-edge ('ito', 'ito')
#  WARN: self-edge ('dive_bomber', 'dive_bomber')
#  WARN: self-edge ('adaline', 'adaline')
#  WARN: self-edge ('gang_war', 'gang_war')
#  WARN: self-edge ('stray_cats', 'stray_cats')
#  WARN: self-edge ('jonah', 'jonah')
#  WARN: self-edge ('ria', 'ria')
#  WARN: self-edge ('rabbit_hole', 'rabbit_hole')
#  WARN: self-edge ('ara', 'ara')
#  WARN: self-edge ('rover', 'rover')
#  WARN: self-edge ('blast', 'blast')
#  WARN: self-edge ('nisa', 'nisa')
#  WARN: self-edge ('kwai', 'kwai')
#  WARN: self-edge ('clap', 'clap')
#  WARN: self-edge ('rocking_chair', 'rocking_chair')
#  WARN: self-edge ('upn', 'upn')
#  WARN: self-edge ('vistajet', 'vistajet')
#  WARN: self-edge ('the_dress', 'the_dress')
#  WARN: self-edge ('personal_shopper', 'personal_shopper')
#  WARN: self-edge ('group_home', 'group_home')
#  WARN: self-edge ('motion_sickness', 'motion_sickness')
#  WARN: self-edge ('haggis', 'haggis')
#  WARN: self-edge ('cas', 'cas')
#  WARN: self-edge ('dox', 'dox')
#  WARN: self-edge ('nuclear_blast', 'nuclear_blast')
#  WARN: self-edge ('tutti_frutti', 'tutti_frutti')
#  WARN: self-edge ('shodan', 'shodan')
#  WARN: self-edge ('rock_candy', 'rock_candy')
#  WARN: self-edge ('ent', 'ent')
#  WARN: self-edge ('ipsos', 'ipsos')
#  WARN: self-edge ('qi', 'qi')
#  WARN: self-edge ('columbus', 'columbus')
#  WARN: self-edge ('ait', 'ait')
#  WARN: self-edge ('alcor', 'alcor')
#  WARN: self-edge ('cif', 'cif')
#  WARN: self-edge ('road_rash', 'road_rash')
#  WARN: self-edge ('hotspot', 'hotspot')
#  WARN: self-edge ('blackberry', 'blackberry')
#  WARN: self-edge ('red_sparrow', 'red_sparrow')
#  WARN: self-edge ('price_tag', 'price_tag')
#  WARN: self-edge ('diabolus_in_musica', 'diabolus_in_musica')
#  WARN: self-edge ('nue', 'nue')
#  WARN: self-edge ('lora', 'lora')
#  WARN: self-edge ('jimjam', 'jimjam')
#  WARN: self-edge ('musical', 'musical')
#  WARN: self-edge ('tru', 'tru')
#  WARN: self-edge ('the_mod_squad', 'the_mod_squad')
#  WARN: self-edge ('stack_overflow', 'stack_overflow')
#  WARN: self-edge ('little_people', 'little_people')
#  WARN: self-edge ('ur', 'ur')
#  WARN: self-edge ('kick_the_can', 'kick_the_can')
#  WARN: self-edge ('dogtown', 'dogtown')
#  WARN: self-edge ('acas', 'acas')
#  WARN: self-edge ('sugar_bowl', 'sugar_bowl')
#  WARN: self-edge ('vast', 'vast')
#  WARN: self-edge ('in_the_closet', 'in_the_closet')
#  WARN: self-edge ('bas', 'bas')
#  WARN: self-edge ('tempo', 'tempo')
#  WARN: self-edge ('sao', 'sao')
#  WARN: self-edge ('kitt', 'kitt')
#  WARN: self-edge ('white_lotus', 'white_lotus')
#  WARN: self-edge ('airheads', 'airheads')
#  WARN: self-edge ('wacom', 'wacom')
#  WARN: self-edge ('private_eye', 'private_eye')
#  WARN: self-edge ('milan', 'milan')
#  WARN: self-edge ('scan', 'scan')
#  WARN: self-edge ('c2c', 'c2c')
#  WARN: self-edge ('fark', 'fark')
#  WARN: self-edge ('net', 'net')
#  WARN: self-edge ('tennet', 'tennet')
#  WARN: self-edge ('didi', 'didi')
#  WARN: self-edge ('ran', 'ran')
#  WARN: self-edge ('pin', 'pin')
#  WARN: self-edge ('acquired_taste', 'acquired_taste')
#  WARN: self-edge ('beauty_shop', 'beauty_shop')
#  WARN: self-edge ('raised_fist', 'raised_fist')
#  WARN: self-edge ('airheads', 'airheads')
#  WARN: self-edge ('survival_game', 'survival_game')
#  WARN: self-edge ('survival_skills', 'survival_skills')
#  WARN: self-edge ('mob_rule', 'mob_rule')
#  WARN: self-edge ('edict', 'edict')
#  WARN: self-edge ('pvp', 'pvp')
#  WARN: self-edge ('extinction_event', 'extinction_event')
#  WARN: self-edge ('sao', 'sao')
#  WARN: self-edge ('blues', 'blues')
#  WARN: self-edge ('brac', 'brac')
#  WARN: self-edge ('state_fair', 'state_fair')
#  WARN: self-edge ("liar's_poker", "liar's_poker")
#  WARN: self-edge ('knock_three_times', 'knock_three_times')
#  WARN: self-edge ('half-breed', 'half-breed')
#  WARN: self-edge ('jazz_standard', 'jazz_standard')
#  WARN: self-edge ('scar', 'scar')
#  WARN: self-edge ('pet', 'pet')
#  WARN: self-edge ('monkey_brains', 'monkey_brains')
#  WARN: self-edge ('shock_jock', 'shock_jock')
#  WARN: self-edge ('lame', 'lame')
#  WARN: self-edge ('crash_dive', 'crash_dive')
#  WARN: self-edge ('kilt', 'kilt')
#  WARN: self-edge ('bowery_boys', 'bowery_boys')
#  WARN: self-edge ('lost_tribe', 'lost_tribe')
#  WARN: self-edge ('ice_cube', 'ice_cube')
#  WARN: self-edge ('meco', 'meco')
#  WARN: self-edge ('mary_garden', 'mary_garden')
#  WARN: self-edge ('beach_house', 'beach_house')
#  WARN: self-edge ('sugar_baby', 'sugar_baby')
#  WARN: self-edge ('waves', 'waves')
#  WARN: self-edge ('meh', 'meh')
#  WARN: self-edge ('context', 'context')
#  WARN: self-edge ('norbit', 'norbit')
#  WARN: self-edge ('radio_silence', 'radio_silence')
#  WARN: self-edge ('nikita', 'nikita')
#  WARN: self-edge ('spa', 'spa')
#  WARN: self-edge ('ted', 'ted')
#  WARN: self-edge ('warren_truss', 'warren_truss')
#  WARN: self-edge ('road_to_nowhere', 'road_to_nowhere')
#  WARN: self-edge ('putty', 'putty')
#  WARN: self-edge ('klos', 'klos')
#  WARN: self-edge ('oboe', 'oboe')
#  WARN: self-edge ('mio', 'mio')
#  WARN: self-edge ('tso', 'tso')
#  WARN: self-edge ('draco', 'draco')
#  WARN: self-edge ('ico', 'ico')
#  WARN: self-edge ('due_date', 'due_date')
#  WARN: self-edge ('gist', 'gist')
#  WARN: self-edge ('zaz', 'zaz')
#  WARN: self-edge ('simca', 'simca')
#  WARN: self-edge ('pace', 'pace')
#  WARN: self-edge ('club_car', 'club_car')
#  WARN: self-edge ('next', 'next')
#  WARN: self-edge ('rank', 'rank')
#  WARN: self-edge ('wise', 'wise')
#  WARN: self-edge ('midlife_crisis', 'midlife_crisis')
#  WARN: self-edge ('jon', 'jon')
#  WARN: self-edge ('international_organization', 'international_organization')
#  WARN: self-edge ('shodan', 'shodan')
#  WARN: self-edge ('mei', 'mei')
#  WARN: self-edge ('roly_poly', 'roly_poly')
#  WARN: self-edge ('bicycle_wheel', 'bicycle_wheel')
#  WARN: self-edge ('spring_green', 'spring_green')
#  WARN: self-edge ('ls', 'ls')
#  WARN: self-edge ('stolen_valor', 'stolen_valor')
#  WARN: self-edge ('fide', 'fide')
#  WARN: self-edge ('rin', 'rin')
#  WARN: self-edge ('trust_company', 'trust_company')
#  WARN: self-edge ('born_again', 'born_again')
#  WARN: self-edge ('factor', 'factor')
#  WARN: self-edge ('klos', 'klos')
#  WARN: self-edge ('roller_skates', 'roller_skates')
#  WARN: self-edge ('road_rage', 'road_rage')
#  WARN: self-edge ('hothouse_flowers', 'hothouse_flowers')
#  WARN: self-edge ('trial_by_combat', 'trial_by_combat')
#  WARN: self-edge ('rai', 'rai')
#  WARN: self-edge ('torque', 'torque')
#  WARN: self-edge ('runaway_train', 'runaway_train')
#  WARN: self-edge ('most', 'most')
#  WARN: self-edge ('soul_food', 'soul_food')
#  WARN: self-edge ('liquid_metal', 'liquid_metal')
#  WARN: self-edge ('tet', 'tet')
#  WARN: self-edge ('raid', 'raid')
#  WARN: self-edge ('vad', 'vad')
#  WARN: self-edge ('death_angel', 'death_angel')
#  WARN: self-edge ('jurist', 'jurist')
#  WARN: self-edge ('edit', 'edit')
#  WARN: self-edge ('ms', 'ms')
#  WARN: self-edge ('gaz', 'gaz')
#  WARN: self-edge ('means_of_production', 'means_of_production')
#  WARN: self-edge ('arc', 'arc')
#  WARN: self-edge ('boy_howdy', 'boy_howdy')
#  WARN: self-edge ('soe', 'soe')
#  WARN: self-edge ('oboe', 'oboe')
#  WARN: self-edge ('powerslave', 'powerslave')
#  WARN: self-edge ('born_again', 'born_again')
#  WARN: self-edge ('semi', 'semi')
#  WARN: self-edge ('kale', 'kale')
#  WARN: self-edge ('green_party', 'green_party')
#  WARN: self-edge ('taylormade', 'taylormade')
#  WARN: self-edge ('cho', 'cho')
#  WARN: self-edge ('era', 'era')
#  WARN: self-edge ('downbeat', 'downbeat')
#  WARN: self-edge ('sic', 'sic')
#  WARN: self-edge ('union_station', 'union_station')
#  WARN: self-edge ('me_at_the_zoo', 'me_at_the_zoo')
#  WARN: self-edge ('mcq', 'mcq')
#  WARN: self-edge ('classic_rock', 'classic_rock')
#  WARN: self-edge ('hotspot', 'hotspot')
#  WARN: self-edge ('balance_of_terror', 'balance_of_terror')
#  WARN: self-edge ('ogg', 'ogg')
#  WARN: self-edge ('deadbeef', 'deadbeef')
#  WARN: self-edge ('tetris_effect', 'tetris_effect')
#  WARN: self-edge ('elisa', 'elisa')
#  WARN: self-edge ('sop', 'sop')
#  WARN: self-edge ('permanent_revolution', 'permanent_revolution')
#  WARN: self-edge ('samo', 'samo')
#  WARN: self-edge ('score', 'score')
#  WARN: self-edge ('weck', 'weck')
#  WARN: self-edge ('elm', 'elm')
#  WARN: self-edge ('product_recall', 'product_recall')
#  WARN: self-edge ('mame', 'mame')
#  WARN: self-edge ('hyena', 'hyena')
#  WARN: self-edge ('bepicolombo', 'bepicolombo')
#  WARN: self-edge ('lem', 'lem')
#  WARN: self-edge ('aro', 'aro')
#  WARN: self-edge ('maven', 'maven')
#  WARN: self-edge ('bal', 'bal')
#  WARN: self-edge ('ecco', 'ecco')
#  WARN: self-edge ('ets', 'ets')
#  WARN: self-edge ('data_matrix', 'data_matrix')
#  WARN: self-edge ('landing_gear', 'landing_gear')
#  WARN: self-edge ('rabbit_test', 'rabbit_test')
#  WARN: self-edge ('police_station', 'police_station')
#  WARN: self-edge ('latex', 'latex')
#  WARN: self-edge ('vi', 'vi')
#  WARN: self-edge ('ria', 'ria')
#  WARN: self-edge ('luna', 'luna')
#  WARN: self-edge ('kaos', 'kaos')
#  WARN: self-edge ('elementary', 'elementary')
#  WARN: self-edge ('six_flags_over_texas', 'six_flags_over_texas')
#  WARN: self-edge ('blue_movie', 'blue_movie')
#  WARN: self-edge ('insight', 'insight')
#  WARN: self-edge ('tea_party', 'tea_party')
#  WARN: self-edge ('god_forbid', 'god_forbid')
#  WARN: self-edge ('integral', 'integral')
#  WARN: self-edge ('iad', 'iad')
#  WARN: self-edge ('iio', 'iio')
#  WARN: self-edge ('forest_green', 'forest_green')
#  WARN: self-edge ('sing!', 'sing!')
#  WARN: self-edge ('y_combinator', 'y_combinator')
#  WARN: self-edge ('total_depravity', 'total_depravity')
#  WARN: self-edge ('xi', 'xi')
#  WARN: self-edge ('nic', 'nic')
#  WARN: self-edge ('common_good', 'common_good')
#  WARN: self-edge ('survey_methodology', 'survey_methodology')
#  WARN: self-edge ('i_spy', 'i_spy')
#  WARN: self-edge ('in_absentia', 'in_absentia')
#  WARN: self-edge ('poodle', 'poodle')
#  WARN: self-edge ('trex', 'trex')
#  WARN: self-edge ('duck_sauce', 'duck_sauce')
#  WARN: self-edge ('wii', 'wii')
#  WARN: self-edge ('source_code', 'source_code')
#  WARN: self-edge ('cart', 'cart')
#  WARN: self-edge ('nisa', 'nisa')
#  WARN: self-edge ('ope', 'ope')
#  WARN: self-edge ('lip_gloss', 'lip_gloss')
#  WARN: self-edge ('match_point', 'match_point')
#  WARN: self-edge ('movable_type', 'movable_type')
#  WARN: self-edge ('bec', 'bec')
#  WARN: self-edge ('bes', 'bes')
#  WARN: self-edge ('slow_motion', 'slow_motion')
#  WARN: self-edge ('master_class', 'master_class')
#  WARN: self-edge ('breakfast_television', 'breakfast_television')
#  WARN: self-edge ('apac', 'apac')
#  WARN: self-edge ('pwn', 'pwn')
#  WARN: self-edge ('talk_radio', 'talk_radio')
#  WARN: self-edge ('random_walk', 'random_walk')
#  WARN: self-edge ('money_train', 'money_train')
#  WARN: self-edge ('move', 'move')
#  WARN: self-edge ('hy', 'hy')
#  WARN: self-edge ('latex', 'latex')
#  WARN: self-edge ('ark', 'ark')
#  WARN: self-edge ('edo', 'edo')
#  WARN: self-edge ('flare_gun', 'flare_gun')
#  WARN: self-edge ('rabbit_hole', 'rabbit_hole')
#  WARN: self-edge ('ryan', 'ryan')
#  WARN: self-edge ('wimp', 'wimp')
#  WARN: self-edge ('omon', 'omon')
#  WARN: self-edge ('major_crimes', 'major_crimes')
#  WARN: self-edge ('mountain_man', 'mountain_man')
#  WARN: self-edge ('odo', 'odo')
#  WARN: self-edge ('ask', 'ask')
#  WARN: self-edge ('ime', 'ime')
#  WARN: self-edge ('ima', 'ima')
#  WARN: self-edge ('tai', 'tai')
#  WARN: self-edge ('medina', 'medina')
#  WARN: self-edge ('ferris_wheel', 'ferris_wheel')
#  WARN: self-edge ('gree', 'gree')
#  WARN: self-edge ('redemption_song', 'redemption_song')
#  WARN: self-edge ('fresh_off_the_boat', 'fresh_off_the_boat')
#  WARN: self-edge ('ripe', 'ripe')
#  WARN: self-edge ('runaway_train', 'runaway_train')
#  WARN: self-edge ('isco', 'isco')
#  WARN: self-edge ('turbojet', 'turbojet')
#  WARN: self-edge ('move', 'move')
#  WARN: self-edge ('fina', 'fina')
#  WARN: self-edge ('tops', 'tops')
#  WARN: self-edge ('live_oak', 'live_oak')
#  WARN: self-edge ('ise', 'ise')
#  WARN: self-edge ('common_good', 'common_good')
#  WARN: self-edge ('av', 'av')
#  WARN: self-edge ('turtles_all_the_way_down', 'turtles_all_the_way_down')
#  WARN: self-edge ('end_zone', 'end_zone')
#  WARN: self-edge ('bond', 'bond')
#  WARN: self-edge ('royal_court', 'royal_court')
#  WARN: self-edge ('foreign_born', 'foreign_born')
#  WARN: self-edge ('ossa', 'ossa')
#  WARN: self-edge ('dupont', 'dupont')
#  WARN: self-edge ('red_sparrow', 'red_sparrow')
#  WARN: self-edge ('fir', 'fir')
#  WARN: self-edge ('c2c', 'c2c')
#  WARN: self-edge ('edx', 'edx')
#  WARN: self-edge ('yara', 'yara')
#  WARN: self-edge ('imx', 'imx')
#  WARN: self-edge ('rot', 'rot')
#  WARN: self-edge ('bel', 'bel')
#  WARN: self-edge ('die_hard', 'die_hard')
#  WARN: self-edge ('fina', 'fina')
#  WARN: self-edge ('white_lion', 'white_lion')
#  WARN: self-edge ('cif', 'cif')
#  WARN: self-edge ('woo', 'woo')
#  WARN: self-edge ('seat', 'seat')
#  WARN: self-edge ('ige', 'ige')
#  WARN: self-edge ('eon', 'eon')
#  WARN: self-edge ('political_psychology', 'political_psychology')
#  WARN: self-edge ('doublethink', 'doublethink')
#  WARN: self-edge ('soa', 'soa')
#  WARN: self-edge ('pax', 'pax')
#  WARN: self-edge ('extremely_large_telescope', 'extremely_large_telescope')
#  WARN: self-edge ('ark', 'ark')
#  WARN: self-edge ('physics_education', 'physics_education')
#  WARN: self-edge ('redcap', 'redcap')
#  WARN: self-edge ('midlife_crisis', 'midlife_crisis')
#  WARN: self-edge ('bhp', 'bhp')
#  WARN: self-edge ('chinese_box', 'chinese_box')
#  WARN: self-edge ('pad', 'pad')
#  WARN: self-edge ('radio_silence', 'radio_silence')
#  WARN: self-edge ('lobster', 'lobster')
#  WARN: self-edge ('doss', 'doss')
#  WARN: self-edge ('curl', 'curl')
#  WARN: self-edge ('bengal_cat', 'bengal_cat')
#  WARN: self-edge ('silent_alarm', 'silent_alarm')
#  WARN: self-edge ('indigo', 'indigo')
#  WARN: self-edge ('linguistic_imperialism', 'linguistic_imperialism')
#  WARN: self-edge ('beauty_shop', 'beauty_shop')
#  WARN: self-edge ('an_officer_and_a_gentleman', 'an_officer_and_a_gentleman')
#  WARN: self-edge ('master_class', 'master_class')
#  WARN: self-edge ('warren_truss', 'warren_truss')
#  WARN: self-edge ('strawberry_shortcake', 'strawberry_shortcake')
#  WARN: self-edge ('divx', 'divx')
#  WARN: self-edge ('trust', 'trust')
#  WARN: self-edge ('hot_air', 'hot_air')
#  WARN: self-edge ('amos', 'amos')
#  WARN: self-edge ('marrs', 'marrs')
#  WARN: self-edge ('cant', 'cant')
#  WARN: self-edge ('dupont', 'dupont')
#  WARN: self-edge ('emotional_intelligence', 'emotional_intelligence')
#  WARN: self-edge ('artistic_license', 'artistic_license')
#  WARN: self-edge ('ideal', 'ideal')
#  WARN: self-edge ('fira', 'fira')
#  WARN: self-edge ('lame', 'lame')
#  WARN: self-edge ('fico', 'fico')
#  WARN: self-edge ('dol', 'dol')
#  WARN: self-edge ('beg', 'beg')
#  WARN: self-edge ('bloc_party', 'bloc_party')
#  WARN: self-edge ('xi', 'xi')
#  WARN: self-edge ('catia', 'catia')
#  WARN: self-edge ('mio', 'mio')
#  WARN: self-edge ('simple', 'simple')
#  WARN: self-edge ('field_of_view', 'field_of_view')
#  WARN: self-edge ('raised_fist', 'raised_fist')
#  WARN: self-edge ('itil', 'itil')
#  WARN: self-edge ('dock', 'dock')
#  WARN: self-edge ('ariel', 'ariel')
#  WARN: self-edge ('rail', 'rail')
#  WARN: self-edge ('yacht_rock', 'yacht_rock')
#  WARN: self-edge ('wassail', 'wassail')
#  WARN: self-edge ('lincoln_green', 'lincoln_green')
#  WARN: self-edge ('ait', 'ait')
#  WARN: self-edge ('glass_house', 'glass_house')
#  WARN: self-edge ('arinc', 'arinc')
#  WARN: self-edge ('matilda', 'matilda')
#  WARN: self-edge ('hart', 'hart')
#  WARN: self-edge ('redemption_song', 'redemption_song')
#  WARN: self-edge ('body_double', 'body_double')
#  WARN: self-edge ('wea', 'wea')
#  WARN: self-edge ('mince', 'mince')
#  WARN: self-edge ('dax', 'dax')
#  WARN: self-edge ('empty_nest', 'empty_nest')
#  WARN: self-edge ('girl_next_door', 'girl_next_door')
#  WARN: self-edge ('rae', 'rae')
#  WARN: self-edge ('adl', 'adl')
#  WARN: self-edge ('prussian_blue', 'prussian_blue')
#  WARN: self-edge ('five_star', 'five_star')
#  WARN: self-edge ('cold_turkey', 'cold_turkey')
#  WARN: self-edge ('once_upon_a_time', 'once_upon_a_time')
#  WARN: self-edge ('open_university', 'open_university')
#  WARN: self-edge ('atomic_blonde', 'atomic_blonde')
#  WARN: self-edge ('bra', 'bra')
#  WARN: self-edge ('krk', 'krk')
#  WARN: self-edge ('rc', 'rc')
#  WARN: self-edge ('lost_world', 'lost_world')
#  WARN: self-edge ('wu', 'wu')
#  WARN: self-edge ('hard_candy', 'hard_candy')
#  WARN: self-edge ('product_recall', 'product_recall')
#  WARN: self-edge ('knox', 'knox')
#  WARN: self-edge ('marauder', 'marauder')
#  WARN: self-edge ('draco', 'draco')
#  WARN: self-edge ('polar_bear', 'polar_bear')
#  WARN: self-edge ('love_hotel', 'love_hotel')
#  WARN: self-edge ('wagon_train', 'wagon_train')
#  WARN: self-edge ('lock_and_key', 'lock_and_key')
#  WARN: self-edge ('imp', 'imp')
#  WARN: self-edge ('do', 'do')
#  WARN: self-edge ('pe', 'pe')
#  WARN: self-edge ('ska', 'ska')
#  WARN: self-edge ('ghost_story', 'ghost_story')
#  WARN: self-edge ('top_model', 'top_model')
#  WARN: self-edge ('reboot', 'reboot')
#  WARN: self-edge ('air_combat', 'air_combat')
#  WARN: self-edge ('cis', 'cis')
#  WARN: self-edge ('turtles_all_the_way_down', 'turtles_all_the_way_down')
#  WARN: self-edge ('hela', 'hela')
#  WARN: self-edge ('elp', 'elp')
#  WARN: self-edge ('gail', 'gail')
#  WARN: self-edge ('cast', 'cast')
#  WARN: self-edge ('warp_and_weft', 'warp_and_weft')
#  WARN: self-edge ('caci', 'caci')
#  WARN: self-edge ('suicidal_tendencies', 'suicidal_tendencies')
#  WARN: self-edge ('dead_man', 'dead_man')
#  WARN: self-edge ('dbm', 'dbm')
#  WARN: self-edge ('dbm', 'dbm')
#  WARN: self-edge ('cyclades', 'cyclades')
#  WARN: self-edge ('amerasian', 'amerasian')
#  WARN: self-edge ('nox', 'nox')
#  WARN: self-edge ('neat', 'neat')
#  WARN: self-edge ('mind_games', 'mind_games')
#  WARN: self-edge ('american_pop', 'american_pop')
#  WARN: self-edge ('crater_lake', 'crater_lake')
#  WARN: self-edge ('real_life', 'real_life')
#  WARN: self-edge ('mezzo_forte', 'mezzo_forte')
#  WARN: self-edge ('nouveau_riche', 'nouveau_riche')
#  WARN: self-edge ('tot', 'tot')
#  WARN: self-edge ('tera', 'tera')
#  WARN: self-edge ('zil', 'zil')
#  WARN: self-edge ('bab', 'bab')
#  WARN: self-edge ('skew', 'skew')
#  WARN: self-edge ('mena', 'mena')
#  WARN: self-edge ('empower', 'empower')
#  WARN: self-edge ('asp', 'asp')
#  WARN: self-edge ('perfect_square', 'perfect_square')
#  WARN: self-edge ('squid', 'squid')
#  WARN: self-edge ('stick_figure', 'stick_figure')
#  WARN: self-edge ('pep', 'pep')
#  WARN: self-edge ('silver_machine', 'silver_machine')
#  WARN: self-edge ('white_lotus', 'white_lotus')
#  WARN: self-edge ('mint', 'mint')
#  WARN: self-edge ('jumping_the_broom', 'jumping_the_broom')
#  WARN: self-edge ('flask', 'flask')
#  WARN: self-edge ('kika', 'kika')
#  WARN: self-edge ('ban', 'ban')
#  WARN: self-edge ('alp', 'alp')
#  WARN: self-edge ('arab_federation', 'arab_federation')
#  WARN: self-edge ('turtle_soup', 'turtle_soup')
#  WARN: self-edge ('ay', 'ay')
#  WARN: self-edge ('ms', 'ms')
#  WARN: self-edge ('rare_bird', 'rare_bird')
#  WARN: self-edge ('ood', 'ood')
#  WARN: self-edge ('cherub', 'cherub')
#  WARN: self-edge ('og', 'og')
#  WARN: self-edge ('interjet', 'interjet')
#  WARN: self-edge ('house_party', 'house_party')
#  WARN: self-edge ('do', 'do')
#  WARN: self-edge ('airdrop', 'airdrop')
#  WARN: self-edge ('the_oa', 'the_oa')
#  WARN: self-edge ('man-at-arms', 'man-at-arms')
#  WARN: self-edge ('due_date', 'due_date')
#  WARN: self-edge ('stu', 'stu')
#  WARN: self-edge ('thug_life', 'thug_life')
#  WARN: self-edge ('pho', 'pho')
#  WARN: self-edge ('ase', 'ase')
#  WARN: self-edge ('ghost_whisperer', 'ghost_whisperer')
#  WARN: self-edge ('panther', 'panther')
#  WARN: self-edge ('crash_dive', 'crash_dive')
#  WARN: self-edge ('chi', 'chi')
#  WARN: self-edge ('swat', 'swat')
#  WARN: self-edge ('eliza', 'eliza')
#  WARN: self-edge ('grits', 'grits')
#  WARN: self-edge ('vast', 'vast')
#  WARN: self-edge ('trump_card', 'trump_card')
#  WARN: self-edge ('bes', 'bes')
#  WARN: self-edge ('oxo', 'oxo')
#  WARN: self-edge ('cattle_drive', 'cattle_drive')
#  WARN: self-edge ('lars', 'lars')
#  WARN: self-edge ('iah', 'iah')
#  WARN: self-edge ('chinese_whispers', 'chinese_whispers')
#  WARN: self-edge ('imx', 'imx')
#  WARN: self-edge ('dutch_oven', 'dutch_oven')
#  WARN: self-edge ('grits', 'grits')
#  WARN: self-edge ('slow_motion', 'slow_motion')
#  WARN: self-edge ('oss', 'oss')
#  WARN: self-edge ('world_news', 'world_news')
#  WARN: self-edge ('source_code', 'source_code')
#  WARN: self-edge ('pound_cake', 'pound_cake')
#  WARN: self-edge ('la_ink', 'la_ink')
#  WARN: self-edge ('cur', 'cur')
#  WARN: self-edge ('group_home', 'group_home')
#  WARN: self-edge ('draco', 'draco')
#  WARN: self-edge ('rum', 'rum')
#  WARN: self-edge ('asa', 'asa')
#  WARN: self-edge ('triac', 'triac')
#  WARN: self-edge ('national_league', 'national_league')
#  WARN: self-edge ('scan', 'scan')
#  WARN: self-edge ('cover_version', 'cover_version')
#  WARN: self-edge ('valis', 'valis')
#  WARN: self-edge ('demon_hunter', 'demon_hunter')
#  WARN: self-edge ('civil_war', 'civil_war')
#  WARN: self-edge ('creo', 'creo')
#  WARN: self-edge ('sako', 'sako')
#  WARN: self-edge ('long_division', 'long_division')
#  WARN: self-edge ('ross_macdonald', 'ross_macdonald')
#  WARN: self-edge ('cap', 'cap')
#  WARN: self-edge ('stick_figure', 'stick_figure')
#  WARN: self-edge ('mi2', 'mi2')
#  WARN: self-edge ('blank_space', 'blank_space')
#  WARN: self-edge ('duo', 'duo')
#  WARN: self-edge ('ran', 'ran')
#  WARN: self-edge ('nek', 'nek')
#  WARN: self-edge ('tie', 'tie')
#  WARN: self-edge ('twi', 'twi')
#  WARN: self-edge ('state_fair', 'state_fair')
#  WARN: self-edge ('discover', 'discover')
#  WARN: self-edge ('chroma_key', 'chroma_key')
#  WARN: self-edge ('camp', 'camp')
#  WARN: self-edge ('class_action', 'class_action')
#  WARN: self-edge ('blackwater_river', 'blackwater_river')
#  WARN: self-edge ('liquid_metal', 'liquid_metal')
#  WARN: self-edge ('osv', 'osv')
#  WARN: self-edge ('jimjam', 'jimjam')
#  WARN: self-edge ('lede', 'lede')
#  WARN: self-edge ('picture_book', 'picture_book')
#  WARN: self-edge ('lee', 'lee')
#  WARN: self-edge ('tea_party', 'tea_party')
#  WARN: self-edge ('fallen', 'fallen')
#  WARN: self-edge ('mop', 'mop')
#  WARN: self-edge ('suicide_bridge', 'suicide_bridge')
#  WARN: self-edge ('photo_booth', 'photo_booth')
#  WARN: self-edge ('fresh_air', 'fresh_air')
#  WARN: self-edge ('adata', 'adata')
#  WARN: self-edge ('five_eyes', 'five_eyes')
#  WARN: self-edge ('top_hat', 'top_hat')
#  WARN: self-edge ('black_cube', 'black_cube')
#  WARN: self-edge ('kuhl', 'kuhl')
#  WARN: self-edge ('humble_pie', 'humble_pie')
#  WARN: self-edge ('high_tension', 'high_tension')
#  WARN: self-edge ('lem', 'lem')
#  WARN: self-edge ('beos', 'beos')
#  WARN: self-edge ('awal', 'awal')
#  WARN: self-edge ('jean', 'jean')
#  WARN: self-edge ('gang_war', 'gang_war')
#  WARN: self-edge ('lava_lake', 'lava_lake')
#  WARN: self-edge ('gamesmaster', 'gamesmaster')
#  WARN: self-edge ('lia', 'lia')
#  WARN: self-edge ('amy_macdonald', 'amy_macdonald')
#  WARN: self-edge ('cabin_fever', 'cabin_fever')
#  WARN: self-edge ('eagle_talon', 'eagle_talon')
#  WARN: self-edge ('cinemax', 'cinemax')
#  WARN: self-edge ('seventh_son_of_a_seventh_son', 'seventh_son_of_a_seventh_son')
#  WARN: self-edge ('craic', 'craic')
#  WARN: self-edge ('sweet_and_sour', 'sweet_and_sour')
#  WARN: self-edge ('sofi', 'sofi')
#  WARN: self-edge ('oar', 'oar')
#  WARN: self-edge ('fresh_off_the_boat', 'fresh_off_the_boat')
#  WARN: self-edge ('clarity', 'clarity')
#  WARN: self-edge ('imaginary_friend', 'imaginary_friend')
#  WARN: self-edge ('california_roll', 'california_roll')
#  WARN: self-edge ('art', 'art')
#  WARN: self-edge ('abuse_of_power', 'abuse_of_power')
#  WARN: self-edge ('nuclear_family', 'nuclear_family')
#  WARN: self-edge ('air_supply', 'air_supply')
#  WARN: self-edge ('dil', 'dil')
#  WARN: self-edge ('shades_of_purple', 'shades_of_purple')
#  WARN: self-edge ('bas', 'bas')
#  WARN: self-edge ('angle_of_repose', 'angle_of_repose')
#  WARN: self-edge ('white_lion', 'white_lion')
#  WARN: self-edge ('strip_mall', 'strip_mall')
#  WARN: self-edge ('wog', 'wog')
#  WARN: self-edge ('core', 'core')
#  WARN: self-edge ('cyclades', 'cyclades')
#  WARN: self-edge ('pet', 'pet')
#  WARN: self-edge ('back_to_school', 'back_to_school')
#  WARN: self-edge ('foreign_policy', 'foreign_policy')
#  WARN: self-edge ('all_is_true', 'all_is_true')
#  WARN: self-edge ('live_oak', 'live_oak')
#  WARN: self-edge ('pais', 'pais')
#  WARN: self-edge ('true_crime', 'true_crime')
#  WARN: self-edge ('pho', 'pho')
#  WARN: self-edge ('flit', 'flit')
#  WARN: self-edge ('koi', 'koi')
#  WARN: self-edge ('arc', 'arc')
#  WARN: self-edge ('chud', 'chud')
#  WARN: self-edge ('kit', 'kit')
#  WARN: self-edge ('mixed_nuts', 'mixed_nuts')
#  WARN: self-edge ('waf', 'waf')
#  WARN: self-edge ('grand_theft_auto', 'grand_theft_auto')
#  WARN: self-edge ('bios', 'bios')
#  WARN: self-edge ('osv', 'osv')
#  WARN: self-edge ('wix', 'wix')
#  WARN: self-edge ('algol', 'algol')
#  WARN: self-edge ('permanent_revolution', 'permanent_revolution')
#  WARN: self-edge ('ufa', 'ufa')
#  WARN: self-edge ('kalpa', 'kalpa')
#  WARN: self-edge ('fred', 'fred')
#  WARN: self-edge ('duck_sauce', 'duck_sauce')
#  WARN: self-edge ('jass', 'jass')
#  WARN: self-edge ('weather_report', 'weather_report')
#  WARN: self-edge ('bhp', 'bhp')
#  WARN: self-edge ('la_ink', 'la_ink')
#  WARN: self-edge ('flash', 'flash')
#  WARN: self-edge ('wash', 'wash')
#  WARN: self-edge ('gail', 'gail')
#  WARN: self-edge ('house_party', 'house_party')
#  WARN: self-edge ('rif', 'rif')
#  WARN: self-edge ('dwm', 'dwm')
#  WARN: self-edge ('core', 'core')
#  WARN: self-edge ('ecco', 'ecco')
#  WARN: self-edge ('spy_fiction', 'spy_fiction')
#  WARN: self-edge ('true_crime', 'true_crime')
#  WARN: self-edge ('bliss', 'bliss')
#  WARN: self-edge ('stride', 'stride')
#  WARN: self-edge ('flo', 'flo')
#  WARN: self-edge ('cold_case', 'cold_case')
#  WARN: self-edge ('aft', 'aft')
#  WARN: self-edge ('red_lobster', 'red_lobster')
#  WARN: self-edge ('house_of_cards', 'house_of_cards')
#  WARN: self-edge ('two-minute_warning', 'two-minute_warning')
#  WARN: self-edge ('secret_service', 'secret_service')
#  WARN: self-edge ('chantilly_lace', 'chantilly_lace')
#  WARN: self-edge ('kik', 'kik')
#  WARN: self-edge ('slim', 'slim')
#  WARN: self-edge ('night_fever', 'night_fever')
#  WARN: self-edge ('flashforward', 'flashforward')
#  WARN: self-edge ('aba', 'aba')
#  WARN: self-edge ('palm', 'palm')
#  WARN: self-edge ('abus', 'abus')
#  WARN: self-edge ('king_street_station', 'king_street_station')
#  WARN: self-edge ('double_negative', 'double_negative')
#  WARN: self-edge ('evil_eye', 'evil_eye')
#  WARN: self-edge ('kitt', 'kitt')
#  WARN: self-edge ('pad', 'pad')
#  WARN: self-edge ('appropriate_adult', 'appropriate_adult')
#  WARN: self-edge ('violet_blue', 'violet_blue')
#  WARN: self-edge ('eh', 'eh')
#  WARN: self-edge ('short_people', 'short_people')
#  WARN: self-edge ('means_of_production', 'means_of_production')
#  WARN: self-edge ('caltrain', 'caltrain')
#  WARN: self-edge ('julian_day', 'julian_day')
#  WARN: self-edge ('postscript', 'postscript')
#  WARN: self-edge ('witching_hour', 'witching_hour')
#  WARN: self-edge ('swat', 'swat')
#  WARN: self-edge ('tut', 'tut')
#  WARN: self-edge ('chop', 'chop')
#  WARN: self-edge ('ola', 'ola')
#  WARN: self-edge ('black-eyed_susan', 'black-eyed_susan')
#  WARN: self-edge ('pwn', 'pwn')
#  WARN: self-edge ('og', 'og')
#  WARN: self-edge ('ross_macdonald', 'ross_macdonald')
#  WARN: self-edge ('local_group', 'local_group')
#  WARN: self-edge ('gef', 'gef')
#  WARN: self-edge ('arch_bridge', 'arch_bridge')
#  WARN: self-edge ('mountain_man', 'mountain_man')
#  WARN: self-edge ('yawl', 'yawl')
#  WARN: self-edge ('mange_tout', 'mange_tout')
#  WARN: self-edge ('suspension_of_disbelief', 'suspension_of_disbelief')
#  WARN: self-edge ('cacao', 'cacao')
#  WARN: self-edge ('goldeneye', 'goldeneye')
#  WARN: self-edge ('wayv', 'wayv')
#  WARN: self-edge ('poodle', 'poodle')
#  WARN: self-edge ('road_rash', 'road_rash')
#  WARN: self-edge ('period_pains', 'period_pains')
#  WARN: self-edge ('gold_nugget', 'gold_nugget')
#  WARN: self-edge ('marco', 'marco')
#  WARN: self-edge ('victory_garden', 'victory_garden')
#  WARN: self-edge ('central_station', 'central_station')
#  WARN: self-edge ('la_paloma', 'la_paloma')
#  WARN: self-edge ('midi', 'midi')
#  WARN: self-edge ('apac', 'apac')
#  WARN: self-edge ('ethane', 'ethane')
#  WARN: self-edge ('night_sweats', 'night_sweats')
#  WARN: self-edge ('supergun', 'supergun')
#  WARN: self-edge ('artistic_license', 'artistic_license')
#  WARN: self-edge ('qube', 'qube')
#  WARN: self-edge ('jio', 'jio')
#  WARN: self-edge ('power_tool', 'power_tool')
#  WARN: self-edge ('norbit', 'norbit')
#  WARN: self-edge ('scar_tissue', 'scar_tissue')
#  WARN: self-edge ('den', 'den')
#  WARN: self-edge ('cid', 'cid')
#  WARN: self-edge ('oa', 'oa')
#  WARN: self-edge ('astor', 'astor')
#  WARN: self-edge ('mush', 'mush')
#  WARN: self-edge ('banana_republic', 'banana_republic')
#  WARN: self-edge ('ara', 'ara')
#  WARN: self-edge ('sox', 'sox')
#  WARN: self-edge ('ets', 'ets')
#  WARN: self-edge ('pocket_universe', 'pocket_universe')
#  WARN: self-edge ('louder_than_bombs', 'louder_than_bombs')
#  WARN: self-edge ('daf', 'daf')
#  WARN: self-edge ('tab', 'tab')
#  WARN: self-edge ('zzz', 'zzz')
#  WARN: self-edge ('teen_mom', 'teen_mom')
#  WARN: self-edge ('gaap', 'gaap')
#  WARN: self-edge ('next', 'next')
#  WARN: self-edge ('chi', 'chi')
#  WARN: self-edge ('donkey_show', 'donkey_show')
#  WARN: self-edge ('seamonkey', 'seamonkey')
#  WARN: self-edge ('madi', 'madi')
#  WARN: self-edge ('glass_onion', 'glass_onion')
#  WARN: self-edge ('hela', 'hela')
#  WARN: self-edge ('spectre', 'spectre')
#  WARN: self-edge ('ll', 'll')
#  WARN: self-edge ('bish', 'bish')
#  WARN: self-edge ('tin_toy', 'tin_toy')
#  WARN: self-edge ('claim_jumper', 'claim_jumper')
#  WARN: self-edge ('foreign_policy', 'foreign_policy')
#  WARN: self-edge ('pace', 'pace')
#  WARN: self-edge ('hue_and_cry', 'hue_and_cry')
#  WARN: self-edge ('high_anxiety', 'high_anxiety')
#  WARN: self-edge ('leon', 'leon')
#  WARN: self-edge ('eagle_eye', 'eagle_eye')
#  WARN: self-edge ('blood_diamond', 'blood_diamond')
#  WARN: self-edge ('airdrop', 'airdrop')
#  WARN: self-edge ('tsst', 'tsst')
#  WARN: self-edge ('metrorail', 'metrorail')
#  WARN: self-edge ('road_trip', 'road_trip')
#  WARN: self-edge ('garage_sale', 'garage_sale')
#  WARN: self-edge ('price_tag', 'price_tag')
#  WARN: self-edge ('spyder', 'spyder')
#  WARN: self-edge ('kdf', 'kdf')
#  WARN: self-edge ('dax', 'dax')
#  WARN: self-edge ('ska', 'ska')
#  WARN: self-edge ('maw', 'maw')
#  WARN: self-edge ('tiff', 'tiff')
#  WARN: self-edge ('rif', 'rif')
#  WARN: self-edge ('gumtree', 'gumtree')
#  WARN: self-edge ('tubular_bells', 'tubular_bells')
#  WARN: self-edge ('peacemaker', 'peacemaker')
#  WARN: self-edge ('imp', 'imp')
#  WARN: self-edge ('bungle_in_the_jungle', 'bungle_in_the_jungle')
#  WARN: self-edge ('vista', 'vista')
#  WARN: self-edge ('amos', 'amos')
#  WARN: self-edge ('wild_turkey', 'wild_turkey')
#  WARN: self-edge ('shades_of_purple', 'shades_of_purple')
#  WARN: self-edge ('blast', 'blast')
#  WARN: self-edge ('loi', 'loi')
#  WARN: self-edge ('bor', 'bor')
#  WARN: self-edge ('wash', 'wash')
#  WARN: self-edge ('uhu', 'uhu')
#  WARN: self-edge ('eau', 'eau')
#  WARN: self-edge ('jesus_wept', 'jesus_wept')
#  WARN: self-edge ('union_station', 'union_station')
#  WARN: self-edge ('significant_other', 'significant_other')
#  WARN: self-edge ('wit', 'wit')
#  WARN: self-edge ('janet', 'janet')
#  WARN: self-edge ('dark_horse', 'dark_horse')
#  WARN: self-edge ('spa', 'spa')
#  WARN: self-edge ('extinction_event', 'extinction_event')
#  WARN: self-edge ('crime', 'crime')
#  WARN: self-edge ('parliamentary_republic', 'parliamentary_republic')
#  WARN: self-edge ('curl', 'curl')
#  WARN: self-edge ('irreconcilable_differences', 'irreconcilable_differences')
#  WARN: self-edge ('silver_link', 'silver_link')
#  WARN: self-edge ('ls', 'ls')
#  WARN: self-edge ('tin', 'tin')
#  WARN: self-edge ('morning_dew', 'morning_dew')
#  WARN: self-edge ('rewe', 'rewe')
#  WARN: self-edge ('black_moon', 'black_moon')
#  WARN: self-edge ('opium_den', 'opium_den')
#  WARN: self-edge ('jio', 'jio')
#  WARN: self-edge ('stem', 'stem')
#  WARN: self-edge ('kuka', 'kuka')
#  WARN: self-edge ('lora', 'lora')
#  WARN: self-edge ('vir', 'vir')
#  WARN: self-edge ('golf_ball', 'golf_ball')
#  WARN: self-edge ('kika', 'kika')
#  WARN: self-edge ('comal', 'comal')
#  WARN: self-edge ('ladder_logic', 'ladder_logic')
#  WARN: self-edge ('udi', 'udi')
#  WARN: self-edge ('smart', 'smart')
#  WARN: self-edge ('victory_garden', 'victory_garden')
#  WARN: self-edge ('antix', 'antix')
#  WARN: self-edge ('private_dancer', 'private_dancer')
#  WARN: self-edge ('focus', 'focus')
#  WARN: self-edge ('airplay', 'airplay')
#  WARN: self-edge ('ubba', 'ubba')
#  WARN: self-edge ('group_sex', 'group_sex')
#  WARN: self-edge ('diabolus_in_musica', 'diabolus_in_musica')
#  WARN: self-edge ('stol', 'stol')
#  WARN: self-edge ('soap', 'soap')
#  WARN: self-edge ('stun', 'stun')
#  WARN: self-edge ('random_walk', 'random_walk')
#  WARN: self-edge ('ripe', 'ripe')
#  WARN: self-edge ('kaba', 'kaba')
#  WARN: self-edge ('fado', 'fado')
#  WARN: self-edge ('mv', 'mv')
#  WARN: self-edge ('smog', 'smog')
#  WARN: self-edge ('mint_condition', 'mint_condition')
#  WARN: self-edge ('mezzo_forte', 'mezzo_forte')
#  WARN: self-edge ('kit', 'kit')
#  WARN: self-edge ('cho', 'cho')
#  WARN: self-edge ('rank', 'rank')
#  WARN: self-edge ('hush_puppies', 'hush_puppies')
#  WARN: self-edge ('qi', 'qi')
#  WARN: self-edge ('itil', 'itil')
#  WARN: self-edge ('haval', 'haval')
#  WARN: self-edge ('sop', 'sop')
#  WARN: self-edge ('mumps', 'mumps')
#  WARN: self-edge ('memory_stick', 'memory_stick')
#  WARN: self-edge ('ped', 'ped')
#  WARN: self-edge ('survival_game', 'survival_game')
#  WARN: self-edge ('ssss', 'ssss')
#  WARN: self-edge ('minimum_viable_product', 'minimum_viable_product')
#  WARN: self-edge ('kek', 'kek')
#  WARN: self-edge ('crow_foot', 'crow_foot')
#  WARN: self-edge ('little_people', 'little_people')
#  WARN: self-edge ('eau', 'eau')
#  WARN: self-edge ('ase', 'ase')
#  WARN: self-edge ('poa', 'poa')
#  WARN: self-edge ('river_city', 'river_city')
#  WARN: self-edge ('popular_science', 'popular_science')
#  WARN: self-edge ('the_dress', 'the_dress')
#  WARN: self-edge ('wacom', 'wacom')
#  WARN: self-edge ('going_postal', 'going_postal')
#  WARN: self-edge ('crater_lake', 'crater_lake')
#  WARN: self-edge ('motion_sickness', 'motion_sickness')
#  WARN: self-edge ('edx', 'edx')
#  WARN: self-edge ('geb', 'geb')
#  WARN: self-edge ('aerojet', 'aerojet')
#  WARN: self-edge ('kilt', 'kilt')
#  WARN: self-edge ('wii', 'wii')
#  WARN: self-edge ('stun', 'stun')
#  WARN: self-edge ('pocket_universe', 'pocket_universe')
#  WARN: self-edge ('pallas', 'pallas')
#  WARN: self-edge ('cabin_boy', 'cabin_boy')
#  WARN: self-edge ('nxt', 'nxt')
#  WARN: self-edge ('waka', 'waka')
#  WARN: self-edge ('taylormade', 'taylormade')
#  WARN: self-edge ('turtle_soup', 'turtle_soup')
#  WARN: self-edge ('pec', 'pec')
#  WARN: self-edge ('zool', 'zool')
#  WARN: self-edge ('national_road', 'national_road')
#  WARN: self-edge ('next_day_air', 'next_day_air')
#  WARN: self-edge ('intercontinental', 'intercontinental')
#  WARN: self-edge ('bad_taste', 'bad_taste')
#  WARN: self-edge ('fruitvale_station', 'fruitvale_station')
#  WARN: self-edge ('bind', 'bind')
#  WARN: self-edge ('wonder_boy', 'wonder_boy')
#  WARN: self-edge ('mga', 'mga')
#  WARN: self-edge ('rams', 'rams')
#  WARN: self-edge ('atlas_network', 'atlas_network')
#  WARN: self-edge ('vizier', 'vizier')
#  WARN: self-edge ('geha', 'geha')
#  WARN: self-edge ('toto', 'toto')
#  WARN: self-edge ('bedrock', 'bedrock')
#  WARN: self-edge ('second_wind', 'second_wind')
#  WARN: self-edge ('appropriate_adult', 'appropriate_adult')
#  WARN: self-edge ('space_cadet', 'space_cadet')
#  WARN: self-edge ('humble_pie', 'humble_pie')
#  WARN: self-edge ('pup', 'pup')
#  WARN: self-edge ('ufa', 'ufa')
#  WARN: self-edge ('electric_universe', 'electric_universe')
#  WARN: self-edge ('red_dwarf', 'red_dwarf')
#  WARN: self-edge ('trust', 'trust')
#  WARN: self-edge ('wu', 'wu')
#  WARN: self-edge ('unleavened_bread', 'unleavened_bread')
#  WARN: self-edge ('mange_tout', 'mange_tout')
#  WARN: self-edge ('messenger', 'messenger')
#  WARN: self-edge ('donda', 'donda')
#  WARN: self-edge ('gnome', 'gnome')
#  WARN: self-edge ('kid', 'kid')
#  WARN: self-edge ('main_course', 'main_course')
#  WARN: self-edge ('wu_wei', 'wu_wei')
#  WARN: self-edge ('mii', 'mii')
#  WARN: self-edge ('kost', 'kost')
#  WARN: self-edge ('love_at_first_sight', 'love_at_first_sight')
#  WARN: self-edge ('noma', 'noma')
#  WARN: self-edge ('business_casual', 'business_casual')
#  WARN: self-edge ('aia', 'aia')
#  WARN: self-edge ('black_oak', 'black_oak')
#  WARN: self-edge ('fresh_air', 'fresh_air')
#  WARN: self-edge ('oss', 'oss')
#  WARN: self-edge ('truck_driver', 'truck_driver')
#  WARN: self-edge ('kith', 'kith')
#  WARN: self-edge ('golden_pheasant', 'golden_pheasant')
#  WARN: self-edge ('blue_movie', 'blue_movie')
#  WARN: self-edge ('culture_of_fear', 'culture_of_fear')
#  WARN: self-edge ('indian_summer', 'indian_summer')
#  WARN: self-edge ('wagon_train', 'wagon_train')
#  WARN: self-edge ('rasp', 'rasp')
#  WARN: self-edge ('bedrock', 'bedrock')
#  WARN: self-edge ('bios', 'bios')
#  WARN: self-edge ('let_there_be_light', 'let_there_be_light')
#  WARN: self-edge ('len', 'len')
#  WARN: self-edge ('madi', 'madi')
#  WARN: self-edge ('jumping_the_broom', 'jumping_the_broom')
#  WARN: self-edge ('amor_fati', 'amor_fati')
#  WARN: self-edge ('mi2', 'mi2')
#  WARN: self-edge ('echelon', 'echelon')
#  WARN: self-edge ('irreconcilable_differences', 'irreconcilable_differences')
#  WARN: self-edge ('gimp', 'gimp')
#  WARN: self-edge ('speech_act', 'speech_act')
#  WARN: self-edge ('just_cause', 'just_cause')
#  WARN: self-edge ('rock', 'rock')
# ...
#  WARN: self-edge ('nox', 'nox')
#  WARN: self-edge ('cyc', 'cyc')
#  WARN: self-edge ('stim', 'stim')
#  WARN: self-edge ('banana_boat', 'banana_boat')
#  WARN: self-edge ('fop', 'fop')
#  WARN: self-edge ('kaws', 'kaws')
#  WARN: self-edge ('alice', 'alice')
#  WARN: self-edge ('going_postal', 'going_postal')
#  WARN: self-edge ('yus', 'yus')
#  WARN: self-edge ('jungle_rot', 'jungle_rot')
#  WARN: self-edge ('jazz_standard', 'jazz_standard')
#  WARN: self-edge ('red_dwarf', 'red_dwarf')
#  WARN: self-edge ('solar', 'solar')
#  WARN: self-edge ('money_train', 'money_train')
#  WARN: self-edge ('perfect_square', 'perfect_square')
#  WARN: self-edge ('bel', 'bel')
#  WARN: self-edge ('pest', 'pest')
#  WARN: self-edge ('tai', 'tai')
#  WARN: self-edge ('suse', 'suse')
#  WARN: self-edge ('cast', 'cast')
#  WARN: self-edge ('amla', 'amla')
#  WARN: self-edge ('vi', 'vi')
#  WARN: self-edge ('shades_of_green', 'shades_of_green')
#  WARN: self-edge ('mena', 'mena')
#  WARN: self-edge ('knock_three_times', 'knock_three_times')
#  WARN: self-edge ('ethane', 'ethane')
#  WARN: self-edge ('auk', 'auk')
#  WARN: self-edge ('kek', 'kek')
#  WARN: self-edge ('hal', 'hal')
#  WARN: self-edge ('where_no_man_has_gone_before', 'where_no_man_has_gone_before')
#  WARN: self-edge ('pla', 'pla')
#  WARN: self-edge ('farmhouse', 'farmhouse')
#  WARN: self-edge ('long_division', 'long_division')
#  WARN: self-edge ('suburbia_(film)', 'suburbia_(film)')
#  WARN: self-edge ('ween', 'ween')
#  WARN: self-edge ('camp', 'camp')
#  WARN: self-edge ('kras', 'kras')
#  WARN: self-edge ('scada', 'scada')
#  WARN: self-edge ('no_direction_home', 'no_direction_home')
#  WARN: self-edge ('sami', 'sami')
#  WARN: self-edge ('ryo', 'ryo')
#  WARN: self-edge ('cruise_control', 'cruise_control')
#  WARN: self-edge ('good_music', 'good_music')
#  WARN: self-edge ('roa', 'roa')
#  WARN: self-edge ('sako', 'sako')
#  WARN: self-edge ('capital_city', 'capital_city')
#  WARN: self-edge ('ikon', 'ikon')
#  WARN: self-edge ('stack_overflow', 'stack_overflow')
#  WARN: self-edge ('school_spirit', 'school_spirit')
#  WARN: self-edge ('suicide_squad', 'suicide_squad')
#  WARN: self-edge ('memory_stick', 'memory_stick')
#  WARN: self-edge ('string', 'string')
#  WARN: self-edge ('stol', 'stol')
#  WARN: self-edge ('international_organization', 'international_organization')
#  WARN: self-edge ('classic_rock', 'classic_rock')
#  WARN: self-edge ('bat', 'bat')
#  WARN: self-edge ('downbeat', 'downbeat')
#  WARN: self-edge ('qube', 'qube')
#  WARN: self-edge ('tab', 'tab')
#  WARN: self-edge ('dead_cat_bounce', 'dead_cat_bounce')
#  WARN: self-edge ('vog', 'vog')
#  WARN: self-edge ('wimp', 'wimp')
#  WARN: self-edge ('tiff', 'tiff')
#  WARN: self-edge ('test_track', 'test_track')
#  WARN: self-edge ('medusa', 'medusa')
#  WARN: self-edge ('me_at_the_zoo', 'me_at_the_zoo')
#  WARN: self-edge ('power_pack', 'power_pack')
#  WARN: self-edge ('school_spirit', 'school_spirit')
#  WARN: self-edge ('lia', 'lia')
#  WARN: self-edge ('kind', 'kind')
#  WARN: self-edge ('killing_machine', 'killing_machine')
#  WARN: self-edge ('ad_council', 'ad_council')
#  WARN: self-edge ('marcos', 'marcos')
#  WARN: self-edge ('elisa', 'elisa')
#  WARN: self-edge ('together', 'together')
#  WARN: self-edge ('soe', 'soe')
#  WARN: self-edge ('ari', 'ari')
#  WARN: self-edge ('red_lobster', 'red_lobster')
#  WARN: self-edge ('theo', 'theo')
#  WARN: self-edge ('boa', 'boa')
#  WARN: self-edge ('fir', 'fir')
#  WARN: self-edge ('six_flags_over_texas', 'six_flags_over_texas')
#  WARN: self-edge ('tubular_bells', 'tubular_bells')
#  WARN: self-edge ('when_pigs_fly', 'when_pigs_fly')
#  WARN: self-edge ('mind_games', 'mind_games')
#  WARN: self-edge ('major_crimes', 'major_crimes')
#  WARN: self-edge ('talc', 'talc')
#  WARN: self-edge ('loran', 'loran')
#  WARN: self-edge ('night_sweats', 'night_sweats')
#  WARN: self-edge ('short_people', 'short_people')
#  WARN: self-edge ('zil', 'zil')
#  WARN: self-edge ('blowout', 'blowout')
#  WARN: self-edge ('ogg', 'ogg')
#  WARN: self-edge ('cis', 'cis')
#  WARN: self-edge ('unifi', 'unifi')
#  WARN: self-edge ('full_house', 'full_house')
#  WARN: self-edge ('sysco', 'sysco')
#  WARN: self-edge ('void', 'void')
#  WARN: self-edge ('life,_the_universe_and_everything', 'life,_the_universe_and_everything')
#  WARN: self-edge ('pup', 'pup')
#  WARN: self-edge ('no_code', 'no_code')
#  WARN: self-edge ('web', 'web')
#  WARN: self-edge ('mary_garden', 'mary_garden')
#  WARN: self-edge ('apt', 'apt')
#  WARN: self-edge ('cannon_fodder', 'cannon_fodder')
#  WARN: self-edge ('wesh', 'wesh')
#  WARN: self-edge ('waka', 'waka')
#  WARN: self-edge ('unit', 'unit')
#  WARN: self-edge ('pin', 'pin')
#  WARN: self-edge ('sleep_cycle', 'sleep_cycle')
#  WARN: self-edge ('red_cell', 'red_cell')
#  WARN: self-edge ('lulu', 'lulu')
#  WARN: self-edge ('mud', 'mud')
#  WARN: self-edge ('jap', 'jap')
#  WARN: self-edge ('indo', 'indo')
#  WARN: self-edge ('in_absentia', 'in_absentia')
#  WARN: self-edge ('active_measures', 'active_measures')
#  WARN: self-edge ('short_time', 'short_time')
#  WARN: self-edge ('aura', 'aura')
#  WARN: self-edge ('sled', 'sled')
#  WARN: self-edge ('rabbit_test', 'rabbit_test')
#  WARN: self-edge ('mop', 'mop')
#  WARN: self-edge ('chop', 'chop')
#  WARN: self-edge ('chex', 'chex')
#  WARN: self-edge ('use', 'use')
#  WARN: self-edge ('twain', 'twain')
#  WARN: self-edge ('fruitvale_station', 'fruitvale_station')
#  WARN: self-edge ('horse_sense', 'horse_sense')
#  WARN: self-edge ('arco', 'arco')
#  WARN: self-edge ('lock_and_key', 'lock_and_key')
#  WARN: self-edge ('pec', 'pec')
#  WARN: self-edge ('echelon', 'echelon')
#  WARN: self-edge ('raid', 'raid')
#  WARN: self-edge ('caltrain', 'caltrain')
#  WARN: self-edge ('av', 'av')
#  WARN: self-edge ('ice_cube', 'ice_cube')
#  WARN: self-edge ('green_party', 'green_party')
#  WARN: self-edge ('loki', 'loki')
#  WARN: self-edge ('ios', 'ios')
#  WARN: self-edge ('gree', 'gree')
#  WARN: self-edge ('whipped_cream', 'whipped_cream')
#  WARN: self-edge ('accident_of_birth', 'accident_of_birth')
#  WARN: self-edge ('beos', 'beos')
#  WARN: self-edge ('eia', 'eia')
#  WARN: self-edge ('sonos', 'sonos')
#  WARN: self-edge ('fan_death', 'fan_death')
#  WARN: self-edge ('i_come_in_peace', 'i_come_in_peace')
#  WARN: self-edge ('huk', 'huk')
#  WARN: self-edge ("liar's_poker", "liar's_poker")
#  WARN: self-edge ('nina', 'nina')
#  WARN: self-edge ('well', 'well')
#  WARN: self-edge ('fatal_attraction', 'fatal_attraction')
#  WARN: self-edge ('class', 'class')
#  WARN: self-edge ('man-at-arms', 'man-at-arms')
#  WARN: self-edge ('private_eye', 'private_eye')
#  WARN: self-edge ('civil_war', 'civil_war')
#  WARN: self-edge ('in_the_closet', 'in_the_closet')
#  WARN: self-edge ('i_spy', 'i_spy')
#  WARN: self-edge ('american_pop', 'american_pop')
#  WARN: self-edge ('ito', 'ito')
#  WARN: self-edge ('hell_night', 'hell_night')
#  WARN: self-edge ('cid', 'cid')
#  WARN: self-edge ('radius', 'radius')
#  WARN: self-edge ('asos', 'asos')
#  WARN: self-edge ('red_wine', 'red_wine')
#  WARN: self-edge ('basic', 'basic')
#  WARN: self-edge ('vix', 'vix')
#  WARN: self-edge ('tsunami_bomb', 'tsunami_bomb')
#  WARN: self-edge ('wild_dogs', 'wild_dogs')
#  WARN: self-edge ('levert', 'levert')
#  WARN: self-edge ('linguistic_imperialism', 'linguistic_imperialism')
#  WARN: self-edge ('die_hard', 'die_hard')
#  WARN: self-edge ('press_gang', 'press_gang')
#  WARN: self-edge ('movable_type', 'movable_type')
#  WARN: self-edge ('slime', 'slime')
#  WARN: self-edge ('asa', 'asa')
#  WARN: self-edge ('curiosity_killed_the_cat', 'curiosity_killed_the_cat')
#  WARN: self-edge ('kitchen_cabinet', 'kitchen_cabinet')
#  WARN: self-edge ("lorenzo's_oil", "lorenzo's_oil")
#  WARN: self-edge ('breakfast_television', 'breakfast_television')
#  WARN: self-edge ('tex', 'tex')
#  WARN: self-edge ('silver_bullet', 'silver_bullet')
#  WARN: self-edge ('phoneme', 'phoneme')
#  WARN: self-edge ('dril', 'dril')
#  WARN: self-edge ('basic_research', 'basic_research')
#  WARN: self-edge ('vic', 'vic')
#  WARN: self-edge ('pi', 'pi')
#  WARN: self-edge ('weather_report', 'weather_report')
#  WARN: self-edge ('diff', 'diff')
#  WARN: self-edge ('apt', 'apt')
#  WARN: self-edge ('qline', 'qline')
#  WARN: self-edge ('joie_de_vivre', 'joie_de_vivre')
#  WARN: self-edge ('national_league', 'national_league')
#  WARN: self-edge ('jet_airliner', 'jet_airliner')
#  WARN: self-edge ('test_track', 'test_track')
#  WARN: self-edge ('hard_candy', 'hard_candy')
#  WARN: self-edge ('chips', 'chips')
#  WARN: self-edge ('dead_cat_bounce', 'dead_cat_bounce')
#  WARN: self-edge ('tex', 'tex')
#  WARN: self-edge ('hwa', 'hwa')
#  WARN: self-edge ('wolf_children', 'wolf_children')
#  WARN: self-edge ('elm', 'elm')
#  WARN: self-edge ('variable_star', 'variable_star')
#  WARN: self-edge ('rabbit_punch', 'rabbit_punch')
#  WARN: self-edge ('clandestine', 'clandestine')
#  WARN: self-edge ('goldeneye', 'goldeneye')
#  WARN: self-edge ('ak', 'ak')
#  WARN: self-edge ('tet', 'tet')
#  WARN: self-edge ('time_of_troubles', 'time_of_troubles')
#  WARN: self-edge ('ped', 'ped')
#  WARN: self-edge ('tin_toy', 'tin_toy')
#  WARN: self-edge ('jonas', 'jonas')
#  WARN: self-edge ('iowa', 'iowa')
#  WARN: self-edge ('sap', 'sap')
#  WARN: self-edge ('iga', 'iga')
#  WARN: self-edge ('chicken_shack', 'chicken_shack')
#  WARN: self-edge ('soul_food', 'soul_food')
#  WARN: self-edge ('metropolitan_railway', 'metropolitan_railway')
#  WARN: self-edge ('paca', 'paca')
#  WARN: self-edge ('police_academy', 'police_academy')
#  WARN: self-edge ('curiosity_killed_the_cat', 'curiosity_killed_the_cat')
#  WARN: self-edge ('indigo', 'indigo')
#  WARN: self-edge ('kitchen_cabinet', 'kitchen_cabinet')
#  WARN: self-edge ('ada', 'ada')
#  WARN: self-edge ('vision_quest', 'vision_quest')
#  WARN: self-edge ('open_university', 'open_university')
#  WARN: self-edge ('giovanni_di_lorenzo', 'giovanni_di_lorenzo')
#  WARN: self-edge ('red_cell', 'red_cell')
#  WARN: self-edge ('adl', 'adl')
#  WARN: self-edge ('house_of_cards', 'house_of_cards')
#  WARN: self-edge ('jet_black', 'jet_black')
#  WARN: self-edge ('kaur', 'kaur')
#  WARN: self-edge ('rams', 'rams')
#  WARN: self-edge ('zaz', 'zaz')
#  WARN: self-edge ('can', 'can')
#  WARN: self-edge ('significant_other', 'significant_other')
#  WARN: self-edge ('xing', 'xing')
#  WARN: self-edge ('sweet_pea', 'sweet_pea')
#  WARN: self-edge ('kaos', 'kaos')
#  WARN: self-edge ('diff', 'diff')
#  WARN: self-edge ('poa', 'poa')
#  WARN: self-edge ('honeymoon_suite', 'honeymoon_suite')
#  WARN: self-edge ('soa', 'soa')
#  WARN: self-edge ('football_manager', 'football_manager')
#  WARN: self-edge ('cacao', 'cacao')
#  WARN: self-edge ('tortilla_soup', 'tortilla_soup')
#  WARN: self-edge ('soap', 'soap')
#  WARN: self-edge ('southern_belle', 'southern_belle')
#  WARN: self-edge ('corpus_delicti', 'corpus_delicti')
#  WARN: self-edge ('ay', 'ay')
#  WARN: self-edge ('pvp', 'pvp')
#  WARN: self-edge ('iga', 'iga')
#  WARN: self-edge ('bliss', 'bliss')
#  WARN: self-edge ('black_oak', 'black_oak')
#  WARN: self-edge ('sing!', 'sing!')
#  WARN: self-edge ('twain', 'twain')
#  WARN: self-edge ('fico', 'fico')
#  WARN: self-edge ('janet', 'janet')
#  WARN: self-edge ('an', 'an')
#  WARN: self-edge ('roh', 'roh')
#  WARN: self-edge ('rin', 'rin')
#  WARN: self-edge ('athens', 'athens')
#  WARN: self-edge ('genesis', 'genesis')
#  WARN: self-edge ('septa', 'septa')
#  WARN: self-edge ('beach_house', 'beach_house')
#  WARN: self-edge ('tcl', 'tcl')
#  WARN: self-edge ('frog', 'frog')
#  WARN: self-edge ('busy_signal', 'busy_signal')
#  WARN: self-edge ('mest', 'mest')
#  WARN: self-edge ('python', 'python')
#  WARN: self-edge ('spyder', 'spyder')
#  WARN: self-edge ('mae', 'mae')
#  WARN: self-edge ('sap', 'sap')
#  WARN: self-edge ('root', 'root')
#  WARN: self-edge ('suicidal_tendencies', 'suicidal_tendencies')
#  WARN: self-edge ('fear_of_the_dark', 'fear_of_the_dark')
#  WARN: self-edge ('mixed_reality', 'mixed_reality')
#  WARN: self-edge ('chinese_box', 'chinese_box')
#  WARN: self-edge ('molle', 'molle')
#  WARN: self-edge ('meg', 'meg')
#  WARN: self-edge ('aba', 'aba')
#  WARN: self-edge ('bill_of_rights', 'bill_of_rights')
#  WARN: self-edge ('vpro', 'vpro')
#  WARN: self-edge ('forest_green', 'forest_green')
#  WARN: self-edge ('onyx', 'onyx')
#  WARN: self-edge ('national_heritage_area', 'national_heritage_area')
#  WARN: self-edge ('venus', 'venus')
#  WARN: self-edge ('ise', 'ise')
#  WARN: self-edge ('southern_belle', 'southern_belle')
#  WARN: self-edge ('past', 'past')
#  WARN: self-edge ('five_star', 'five_star')
#  WARN: self-edge ('sic', 'sic')
#  WARN: self-edge ('len', 'len')
#  WARN: self-edge ('gnome', 'gnome')
#  WARN: self-edge ('double_negative', 'double_negative')
#  WARN: self-edge ('ima', 'ima')
#  WARN: self-edge ('chroma_key', 'chroma_key')
#  WARN: self-edge ('blood_diamond', 'blood_diamond')
#  WARN: self-edge ('earthbound', 'earthbound')
#  WARN: self-edge ('ur', 'ur')
#  WARN: self-edge ('sampson', 'sampson')
#  WARN: self-edge ('comic_relief', 'comic_relief')
#  WARN: self-edge ('isar', 'isar')
#  WARN: self-edge ('next_of_kin', 'next_of_kin')
#  WARN: self-edge ('glass_house', 'glass_house')
#  WARN: self-edge ('dive_bomber', 'dive_bomber')
#  WARN: self-edge ('balance_of_terror', 'balance_of_terror')
#  WARN: self-edge ('bdd', 'bdd')
#  WARN: self-edge ('counterpunch', 'counterpunch')
#  WARN: self-edge ('pound_cake', 'pound_cake')
#  WARN: self-edge ('protection_racket', 'protection_racket')
#  WARN: self-edge ('metropolitan_railway', 'metropolitan_railway')
#  WARN: self-edge ('dbm', 'dbm')
#  WARN: self-edge ('dbm', 'dbm')
#  WARN: self-edge ('pla', 'pla')
#  WARN: self-edge ('specs', 'specs')
#  WARN: self-edge ('ivo', 'ivo')
#  WARN: self-edge ('divx', 'divx')
#  WARN: self-edge ('night_terror', 'night_terror')
#  WARN: self-edge ('necessary_evil', 'necessary_evil')
#  WARN: self-edge ('ted', 'ted')
#  WARN: self-edge ('mix', 'mix')
#  WARN: self-edge ('morning_dew', 'morning_dew')
#  WARN: self-edge ('hue_and_cry', 'hue_and_cry')
#  WARN: self-edge ('seventh_son_of_a_seventh_son', 'seventh_son_of_a_seventh_son')
#  WARN: self-edge ('spring', 'spring')
#  WARN: self-edge ('stolen_valor', 'stolen_valor')
#  WARN: self-edge ('aro', 'aro')
#  WARN: self-edge ('rough_diamond', 'rough_diamond')
#  WARN: self-edge ('kik', 'kik')
#  WARN: self-edge ('ibb', 'ibb')
#  WARN: self-edge ('woke', 'woke')
#  WARN: self-edge ('mata', 'mata')
#  WARN: self-edge ('salad_days', 'salad_days')
#  WARN: self-edge ('gaap', 'gaap')
#  WARN: self-edge ('kick_the_can', 'kick_the_can')
#  WARN: self-edge ('power_pack', 'power_pack')
#  WARN: self-edge ('gravel_pit', 'gravel_pit')
#  WARN: self-edge ('pae', 'pae')
#  WARN: self-edge ('fucked_up', 'fucked_up')
#  WARN: self-edge ('emi', 'emi')
#  WARN: self-edge ('toto', 'toto')
#  WARN: self-edge ('make_believe', 'make_believe')
#  WARN: self-edge ('ipsos', 'ipsos')
#  WARN: self-edge ('bengal_cat', 'bengal_cat')
#  WARN: self-edge ('waves', 'waves')
#  WARN: self-edge ('gia', 'gia')
#  WARN: self-edge ('sweet_and_sour', 'sweet_and_sour')
#  WARN: self-edge ('class_action', 'class_action')
#  WARN: self-edge ('dead_man', 'dead_man')
#  WARN: self-edge ('jet_airliner', 'jet_airliner')
#  WARN: self-edge ('violet_blue', 'violet_blue')
#  WARN: self-edge ('virtual_console', 'virtual_console')
#  WARN: self-edge ('peach', 'peach')
#  WARN: self-edge ('witching_hour', 'witching_hour')
#  WARN: self-edge ('roly_poly', 'roly_poly')
#  WARN: self-edge ('mcq', 'mcq')
#  WARN: self-edge ('philadelphia_soul', 'philadelphia_soul')
#  WARN: self-edge ('alma', 'alma')
#  WARN: self-edge ('mom_jeans', 'mom_jeans')
#  WARN: self-edge ('des', 'des')
#  WARN: self-edge ('royal_court', 'royal_court')
#  WARN: self-edge ('horseshoe_theory', 'horseshoe_theory')
#  WARN: self-edge ('broadway_theatre', 'broadway_theatre')
#  WARN: self-edge ('didi', 'didi')
#  WARN: self-edge ('frontrunner', 'frontrunner')
#  WARN: self-edge ('data_matrix', 'data_matrix')
#  WARN: self-edge ('gamemaker', 'gamemaker')
#  WARN: self-edge ('no_direction_home', 'no_direction_home')
#  WARN: self-edge ('fits', 'fits')
#  WARN: self-edge ('snafu', 'snafu')
#  WARN: self-edge ('wog', 'wog')
#  WARN: self-edge ('agricola', 'agricola')
#  WARN: self-edge ('death_angel', 'death_angel')
#  WARN: self-edge ('score', 'score')
#  WARN: self-edge ('arte', 'arte')
#  WARN: self-edge ('anfo', 'anfo')
#  WARN: self-edge ('marcos', 'marcos')
#  WARN: self-edge ('cinemax', 'cinemax')
#  WARN: self-edge ('jon', 'jon')
#  WARN: self-edge ('ryan', 'ryan')
# 243640

# %%
random.seed(42)
random_start = random.choice(list(graph_201901.nodes()))
random_start
# Out:
# 'the_broken_star'

# %%
trans_matrix = get_transition_matrix(graph_201901)

# %%
test_transition_matrix(trans_matrix)
# Out:
# Sinks: 0
# Non-zero cols: 243641
# Non-zero cols are stochastic:
# False

# %%
trans_matrix.sum(axis=0).sum()
# Out:
# 243641.9999958956

# %%
trans_matrix.shape
# Out:
# (243641, 243641)

# %%
stationary = get_stationary_dis(trans_matrix)
stationary
# Out:
# array([6.10806979e-20, 3.07155632e-21, 7.42694142e-21, ...,
#        2.21213797e-21, 1.22073429e-21, 2.46113681e-16])

# %%
random_walk(graph_201901, trans_matrix, stationary, random_start)
# Out:
# Random Walker Progress:   7%|▋         | 71055/1000000.0 [11:06<2:25:56, 106.09it/s]
